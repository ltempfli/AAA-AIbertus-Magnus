# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
import folium
import h3
import geopandas as gpd
import geojson

# %%
df = pd.read_csv(
    "../data/analytics_trip_data.csv",
    index_col=None,
    dtype={
        'payment_type': 'category',
        'company': 'category'
    },     
    parse_dates=['trip_start_timestamp','trip_middle_timestamp','trip_end_timestamp'])

# %%
pd.set_option('display.max_columns', None)
df.describe()
# Out:
#                 trip_start_timestamp             trip_end_timestamp  \
# count                       14562028                       14562028
# mean   2018-06-26 19:03:04.683017984  2018-06-26 19:17:55.079018240
# min              2018-01-01 00:15:00            2018-01-01 00:15:00
# 25%              2018-04-01 00:30:00            2018-04-01 00:45:00
# 50%              2018-06-20 20:30:00            2018-06-20 20:45:00
# 75%              2018-09-22 21:00:00            2018-09-22 21:15:00
# max              2018-12-30 23:45:00            2018-12-31 01:30:00
# std                              NaN                            NaN
#
#        trip_seconds    trip_miles  pickup_census_tract  dropoff_census_tract  \
# count  1.456203e+07  1.456203e+07         1.137150e+07          1.137150e+07
# mean   8.885241e+02  4.092234e+00         1.703139e+10          1.703136e+10
# min    6.100000e+01  1.600000e-01         1.703101e+10          1.703101e+10
# 25%    4.030000e+02  1.000000e+00         1.703108e+10          1.703108e+10
# 50%    6.030000e+02  1.700000e+00         1.703128e+10          1.703128e+10
# 75%    1.026000e+03  4.000000e+00         1.703184e+10          1.703183e+10
# max    7.199000e+03  4.993000e+01         1.703198e+10          1.703198e+10
# std    7.941427e+02  5.353668e+00         3.416295e+05          3.279729e+05
#
#        pickup_community_area  dropoff_community_area          fare  \
# count           1.456157e+07            1.450446e+07  1.456203e+07
# mean            2.536240e+01            2.222967e+01  1.425125e+01
# min             1.000000e+00            1.000000e+00  0.000000e+00
# 25%             8.000000e+00            8.000000e+00  6.500000e+00
# 50%             2.800000e+01            2.400000e+01  8.500000e+00
# 75%             3.200000e+01            3.200000e+01  1.500000e+01
# max             7.700000e+01            7.700000e+01  9.250000e+03
# std             1.981870e+01            1.724037e+01  1.988032e+01
#
#                tips       tolls        extras    trip_total  \
# count  1.456203e+07  11550213.0  1.456203e+07  1.456203e+07
# mean   1.844400e+00         0.0  8.380897e-01  1.707727e+01
# min    0.000000e+00         0.0  0.000000e+00  0.000000e+00
# 25%    0.000000e+00         0.0  0.000000e+00  7.750000e+00
# 50%    0.000000e+00         0.0  0.000000e+00  1.050000e+01
# 75%    2.400000e+00         0.0  1.000000e+00  1.725000e+01
# max    8.000000e+02         0.0  9.832430e+03  9.871430e+03
# std    2.895430e+00         0.0  9.218098e+00  2.370150e+01
#
#                trip_middle_timestamp  price_per_mile  miles_per_hour  \
# count                       14562028    1.456160e+07    1.456203e+07
# mean   2018-06-26 19:10:29.881018368    1.460164e+01    1.377499e+01
# min              2018-01-01 00:15:00    1.000000e-02    1.000215e+00
# 25%              2018-04-01 00:37:30    7.000000e+00    8.250000e+00
# 50%              2018-06-20 20:37:30    9.000000e+00    1.109589e+01
# 75%              2018-09-22 21:07:30    1.500000e+01    1.666667e+01
# max              2018-12-31 00:30:00    1.333757e+04    5.000000e+01
# std                              NaN    2.145791e+01    8.358539e+00
#
#         temperature  precipitation
# count  1.456203e+07   1.456203e+07
# mean   1.209902e+01   2.732992e-03
# min   -2.277778e+01   0.000000e+00
# 25%    2.222222e+00   0.000000e+00
# 50%    1.055556e+01   0.000000e+00
# 75%    2.277778e+01   0.000000e+00
# max    3.555556e+01   1.100000e+00
# std    1.179423e+01   2.687785e-02

# %%
df.head()
# Out:
#                                     trip_id  \
# 0  ac1fae1544d7804f13fbf657cb058ba91a983fea
# 1  31c416218f80ee2e585777bb475243b971504afc
# 2  b0a993338c200b1a3fea0d5602717c61c6b09eef
# 3  f93672d654d2821cfcc49150ff961a8fe281e61d
# 4  1ffa4782096d433dc69fccbbc84326c442644e73
#
#                                              taxi_id trip_start_timestamp  \
# 0  847cf962bd6f62040673e6c24c24940aeb2d7fdaa54677...  2018-01-01 00:15:00
# 1  034ec4437f304cffcd4acf850106574343e69d3c5424ac...  2018-01-01 00:15:00
# 2  196d444ac93f57f7f4d7f4dde1753987581e0917e5f4e0...  2018-01-01 00:15:00
# 3  4563c3624d5325c354809e64158cc6d81e8f2254128a84...  2018-01-01 00:15:00
# 4  97ef85617790d7002c54286661e8d65eb3fe172022c50d...  2018-01-01 00:15:00
#
#    trip_end_timestamp  trip_seconds  trip_miles  pickup_census_tract  \
# 0 2018-01-01 00:30:00         960.0         2.6         1.703107e+10
# 1 2018-01-01 00:30:00         523.0         2.6                  NaN
# 2 2018-01-01 00:30:00         308.0         1.3                  NaN
# 3 2018-01-01 00:15:00         381.0         1.3         1.703108e+10
# 4 2018-01-01 00:15:00         403.0         0.9         1.703108e+10
#
#    dropoff_census_tract  pickup_community_area  dropoff_community_area   fare  \
# 0          1.703108e+10                    7.0                     8.0  11.00
# 1                   NaN                   77.0                    14.0   9.75
# 2                   NaN                    6.0                     7.0   6.25
# 3          1.703184e+10                    8.0                    32.0   6.75
# 4          1.703132e+10                    8.0                    32.0   6.25
#
#    tips  tolls  extras  trip_total payment_type                    company  \
# 0   0.0    0.0     0.0       11.00         Cash  Taxi Affiliation Services
# 1   2.0    NaN     0.0       11.75  Credit Card                  Flash Cab
# 2   2.0    NaN     0.0        8.25  Credit Card                  Flash Cab
# 3   3.0    NaN     0.0        9.75  Credit Card                  Flash Cab
# 4   2.0    NaN     1.0        9.25  Credit Card                  Flash Cab
#
#                pickup_centroid_location  \
# 0  POINT (-87.6317173661 41.9146162864)
# 1  POINT (-87.6634164054 41.9867117999)
# 2  POINT (-87.6559981815 41.9442266014)
# 3  POINT (-87.6288741572 41.8920726347)
# 4  POINT (-87.6188683546 41.8909220259)
#
#                   dropoff_centroid_location  h3_res_4_pickup h3_res_4_dropoff  \
# 0  POINT (-87.6266589003 41.90752007470001)  842664dffffffff  842664dffffffff
# 1          POINT (-87.7215590627 41.968069)  842664dffffffff  842664dffffffff
# 2      POINT (-87.6494887289 41.9226862843)  842664dffffffff  842664dffffffff
# 3      POINT (-87.6314065252 41.8710158803)  842664dffffffff  842664dffffffff
# 4      POINT (-87.6209929134 41.8849871918)  842664dffffffff  842664dffffffff
#
#    h3_res_6_pickup h3_res_6_dropoff  h3_res_8_pickup h3_res_8_dropoff  \
# 0  862664c17ffffff  862664c17ffffff  882664c115fffff  882664c117fffff
# 1  862664d8fffffff  862664ca7ffffff  882664d88bfffff  882664d993fffff
# 2  862664c17ffffff  862664c17ffffff  882664c163fffff  882664c107fffff
# 3  862664c1fffffff  862664c1fffffff  882664c1e1fffff  882664c1a3fffff
# 4  862664c1fffffff  862664c1fffffff  882664c1e3fffff  882664c1e3fffff
#
#    h3_res_9_pickup h3_res_9_dropoff trip_middle_timestamp  price_per_mile  \
# 0  892664c114fffff  892664c116fffff   2018-01-01 00:22:30       11.000000
# 1  892664d88bbffff  892664d9937ffff   2018-01-01 00:22:30        9.750000
# 2  892664c1607ffff  892664c13d3ffff   2018-01-01 00:22:30        6.250000
# 3  892664c1e0fffff  892664c1a07ffff   2018-01-01 00:15:00        6.750000
# 4  892664c1e33ffff  892664c1e2fffff   2018-01-01 00:15:00        7.361111
#
#    miles_per_hour                 date  temperature  precipitation
# 0        9.750000  2018-01-01 01:53:00   -18.333333            0.0
# 1       17.896750  2018-01-01 01:53:00   -18.333333            0.0
# 2       15.194805  2018-01-01 01:53:00   -18.333333            0.0
# 3       12.283465  2018-01-01 01:53:00   -18.333333            0.0
# 4        8.039702  2018-01-01 01:53:00   -18.333333            0.0

# %% [markdown]
# # Choropleth Maps

# %%
def create_choropleth(dataframe,h3geocol,datacol,legend_name):
    grouped_data = dataframe.groupby(dataframe[h3geocol])[datacol].mean().reset_index()
    m = folium.Map(location=[41.8781, -87.6298], zoom_start=10)
    
    geojson_data = {
        'type': 'FeatureCollection',
        'features': []
    }
    
    for index, row in grouped_data.iterrows():
        geometry = {'type': 'Polygon', 'coordinates': [h3.h3_to_geo_boundary(row[h3geocol], geo_json=True)]}
        feature = {'type': 'Feature', 'geometry': geometry, 'properties': {f'{h3geocol}': row[h3geocol],f'{datacol}': row[datacol]}}
        geojson_data['features'].append(feature)
        
    cp = folium.Choropleth(
        geo_data=geojson_data,
        data=grouped_data,
        columns=[h3geocol, datacol],
        key_on=f'feature.properties.{h3geocol}',
        fill_color='YlGnBu',
        fill_opacity=0.7,
        line_opacity=0.2,
        legend_name=legend_name
    ).add_to(m)

    folium.GeoJsonTooltip([h3geocol,datacol]).add_to(cp.geojson)
    
    return m

def create_choropleth_size(dataframe, h3geocol, legend_name):
    # Count the number of rides per H3 hexagon
    grouped_data = dataframe.groupby(h3geocol).size().reset_index(name='total_rides')
    
    # Create a base map
    m = folium.Map(location=[41.8781, -87.6298], zoom_start=10)
    
    # Create GeoJSON data
    geojson_data = {
        'type': 'FeatureCollection',
        'features': []
    }
    
    # Generate GeoJSON features for each H3 hexagon
    for index, row in grouped_data.iterrows():
        geometry = {
            'type': 'Polygon',
            'coordinates': [h3.h3_to_geo_boundary(row[h3geocol], geo_json=True)]
        }
        feature = {
            'type': 'Feature',
            'geometry': geometry,
            'properties': {
                f'{h3geocol}': row[h3geocol],
                'total_rides': row['total_rides']
            }
        }
        geojson_data['features'].append(feature)
    
    # Create the choropleth map
    folium.Choropleth(
        geo_data=geojson_data,
        data=grouped_data,
        columns=[h3geocol, 'total_rides'],  # Ensure columns are correct
        key_on=f'feature.properties.{h3geocol}',
        fill_color='YlGnBu',
        fill_opacity=0.7,
        line_opacity=0,  # Remove outlines
        legend_name=legend_name
    ).add_to(m)
    
    # Add tooltips to display H3 ID and number of rides
    folium.GeoJsonTooltip(
        fields=[h3geocol, 'total_rides'],
        aliases=['H3 ID:', legend_name]
    ).add_to(folium.GeoJson(geojson_data).add_to(m))
    
    return m

# %%
create_choropleth_size(df,"h3_res_9_pickup","Total trips")
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_212536112091f382fdf341a8180968a4 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/d3/3.5.5/d3.min.js&quot;&gt;&lt;/script&gt;
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_212536112091f382fdf341a8180968a4&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_212536112091f382fdf341a8180968a4 = L.map(
#                 &quot;map_212536112091f382fdf341a8180968a4&quot;,
#                 {
#                     center: [41.8781, -87.6298],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_8f8cb087e0ca5030272f5cf27e6ca3e3 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_8f8cb087e0ca5030272f5cf27e6ca3e3.addTo(map_212536112091f382fdf341a8180968a4);
#
#
#             var choropleth_2c61e6ad592c828d4aee84d8d9324157 = L.featureGroup(
#                 {}
#             );
#
#
#         function geo_json_bf075afd9d8f92a8c59a6c83aaafa7eb_styler(feature) {
#             switch(feature.properties.h3_res_9_pickup) {
#                 case &quot;89266419157ffff&quot;: case &quot;89266419493ffff&quot;: case &quot;89266419607ffff&quot;: case &quot;892664520afffff&quot;: case &quot;89266452147ffff&quot;: case &quot;89266452183ffff&quot;: case &quot;89266452513ffff&quot;: case &quot;89266452533ffff&quot;: case &quot;89266452c87ffff&quot;: case &quot;89266452dabffff&quot;: case &quot;89266456067ffff&quot;: case &quot;89266456137ffff&quot;: case &quot;892664562dbffff&quot;: case &quot;89266456393ffff&quot;: case &quot;89266456413ffff&quot;: case &quot;89266457013ffff&quot;: case &quot;892664c1007ffff&quot;: case &quot;892664c100bffff&quot;: case &quot;892664c101bffff&quot;: case &quot;892664c102fffff&quot;: case &quot;892664c1047ffff&quot;: case &quot;892664c104fffff&quot;: case &quot;892664c1057ffff&quot;: case &quot;892664c105bffff&quot;: case &quot;892664c1067ffff&quot;: case &quot;892664c106fffff&quot;: case &quot;892664c1077ffff&quot;: case &quot;892664c108fffff&quot;: case &quot;892664c10cbffff&quot;: case &quot;892664c10d3ffff&quot;: case &quot;892664c10d7ffff&quot;: case &quot;892664c10dbffff&quot;: case &quot;892664c114fffff&quot;: case &quot;892664c116fffff&quot;: case &quot;892664c1217ffff&quot;: case &quot;892664c1233ffff&quot;: case &quot;892664c124bffff&quot;: case &quot;892664c1257ffff&quot;: case &quot;892664c1267ffff&quot;: case &quot;892664c126bffff&quot;: case &quot;892664c1293ffff&quot;: case &quot;892664c129bffff&quot;: case &quot;892664c12b3ffff&quot;: case &quot;892664c12bbffff&quot;: case &quot;892664c12d7ffff&quot;: case &quot;892664c12dbffff&quot;: case &quot;892664c1313ffff&quot;: case &quot;892664c1327ffff&quot;: case &quot;892664c1333ffff&quot;: case &quot;892664c1377ffff&quot;: case &quot;892664c1383ffff&quot;: case &quot;892664c13afffff&quot;: case &quot;892664c13b7ffff&quot;: case &quot;892664c13bbffff&quot;: case &quot;892664c13cfffff&quot;: case &quot;892664c13d3ffff&quot;: case &quot;892664c13dbffff&quot;: case &quot;892664c144bffff&quot;: case &quot;892664c144fffff&quot;: case &quot;892664c1607ffff&quot;: case &quot;892664c160fffff&quot;: case &quot;892664c1617ffff&quot;: case &quot;892664c161bffff&quot;: case &quot;892664c162fffff&quot;: case &quot;892664c1633ffff&quot;: case &quot;892664c163bffff&quot;: case &quot;892664c1643ffff&quot;: case &quot;892664c1657ffff&quot;: case &quot;892664c1663ffff&quot;: case &quot;892664c166bffff&quot;: case &quot;892664c1677ffff&quot;: case &quot;892664c167bffff&quot;: case &quot;892664c168fffff&quot;: case &quot;892664c1693ffff&quot;: case &quot;892664c16a3ffff&quot;: case &quot;892664c16abffff&quot;: case &quot;892664c16bbffff&quot;: case &quot;892664c16c7ffff&quot;: case &quot;892664c16dbffff&quot;: case &quot;892664c1a07ffff&quot;: case &quot;892664c1a63ffff&quot;: case &quot;892664c1aa7ffff&quot;: case &quot;892664c1b0bffff&quot;: case &quot;892664c1b47ffff&quot;: case &quot;892664c1b6fffff&quot;: case &quot;892664c1e5bffff&quot;: case &quot;892664c1e8fffff&quot;: case &quot;892664c1ea7ffff&quot;: case &quot;892664c1ec7ffff&quot;: case &quot;892664c1ed3ffff&quot;: case &quot;892664c1ed7ffff&quot;: case &quot;892664c80afffff&quot;: case &quot;892664c81b7ffff&quot;: case &quot;892664c8317ffff&quot;: case &quot;892664c896fffff

# %%
create_choropleth(df,"h3_res_6_pickup","trip_seconds","Average Total trip seconds")
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_2d5107c924a0d3271351da3133fd6553 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/d3/3.5.5/d3.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_2d5107c924a0d3271351da3133fd6553&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_2d5107c924a0d3271351da3133fd6553 = L.map(
#                 &quot;map_2d5107c924a0d3271351da3133fd6553&quot;,
#                 {
#                     center: [41.8781, -87.6298],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_f56326b63a0c2fb5ebf70c1e91fd3c7d = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_f56326b63a0c2fb5ebf70c1e91fd3c7d.addTo(map_2d5107c924a0d3271351da3133fd6553);
#
#
#             var choropleth_d8207d67dda8c1bf6b2f3e3ce2910a0b = L.featureGroup(
#                 {}
#             );
#
#
#         function geo_json_ebe437104ef9abe1f6d6b392dd262f37_styler(feature) {
#             switch(feature.properties.h3_res_6_pickup) {
#                 case &quot;862664197ffffff&quot;: case &quot;862664567ffffff&quot;: case &quot;862664c87ffffff&quot;: case &quot;862664c8fffffff&quot;: case &quot;862664cc7ffffff&quot;: case &quot;862664ccfffffff&quot;: case &quot;862664cd7ffffff&quot;: case &quot;862664cdfffffff&quot;: case &quot;862664cefffffff&quot;: case &quot;86275936fffffff&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#7fcdbb&quot;, &quot;fillOpacity&quot;: 0.7, &quot;opacity&quot;: 0.2, &quot;weight&quot;: 1};
#                 case &quot;8626641b7ffffff&quot;: case &quot;862664d87ffffff&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#2c7fb8&quot;, &quot;fillOpacity&quot;: 0.7, &quot;opacity&quot;: 0.2, &quot;weight&quot;: 1};
#                 case &quot;862664527ffffff&quot;: case &quot;86266452fffffff&quot;: case &quot;86266456fffffff&quot;: case &quot;862664577ffffff&quot;: case &quot;86275934fffffff&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#41b6c4&quot;, &quot;fillOpacity&quot;: 0.7, &quot;opacity&quot;: 0.2, &quot;weight&quot;: 1};
#                 case &quot;862664c17ffffff&quot;: case &quot;862664c1fffffff&quot;: case &quot;862664ca7ffffff&quot;: case &quot;862664cafffffff&quot;: case &quot;862664d8fffffff&quot;: case &quot;862664d9fffffff&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#ffffcc&quot;, &quot;fillOpacity&quot;: 0.7, &quot;opacity&quot;: 0.2, &quot;weight&quot;: 1};
#                 case &quot;862664cb7ffffff&quot;: case &quot;862664ce7ffffff&quot;: case &quot;862664cf7ffffff&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#c7e9b4&quot;, &quot;fillOpacity&quot;: 0.7, &quot;opacity&quot;: 0.2, &quot;weight&quot;: 1};
#                 default:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#253494&quot;, &quot;fillOpacity&quot;: 0.7, &quot;opacity&quot;: 0.2, &quot;weight&quot;: 1};
#             }
#         }
#
#         function geo_json_ebe437104ef9abe1f6d6b392dd262f37_onEachFeature(feature, layer) {
#             layer.on({
#             });
#         };
#         var geo_json_ebe437104ef9abe1f6d6b392dd262f37 = L.geoJson(null, {
#                 onEachFeature: geo_json_ebe437104ef9abe1f6d6b392dd262f37_onEachFeature,
#
#                 style: geo_json_ebe437104ef9abe1f6d6b392dd262f37_styler,
#         });
#
#         function geo_json_ebe437104ef9abe1f6d6b392dd262f37_add (data) {
#             geo_json_ebe437104ef9abe1f6d6b392dd262f37
#                 .addData(data);
#         }
#             geo_json_ebe437104ef9abe1f6d6b392dd262f37_add({&quot;features&quot;: [{&quot;geometry&quot;: {&quot;coordinates&quot;: [[[-87.5484582247687, 41.7093870868261], [-87.59059738584097, 41.6968108221747], [-87.59514455597292, 41.66432862015156], [-87.55760864113398, 41.644425583726324], [-87.51550479445925, 41.65697962548985], [-87.51090155949316, 41.68945890866503], [-87.5484582247687, 41.7093870868261]]], &quot;type&quot;: &quot;Polygon&quot;}, &quot;properties&quot;: {&quot;h3_res_6_pickup&quot

# %%
create_choropleth(df,"h3_res_8_dropoff","price_per_mile","Average price per mile")
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_d208ea63e0c781c179c83c0e52211328 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/d3/3.5.5/d3.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_d208ea63e0c781c179c83c0e52211328&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_d208ea63e0c781c179c83c0e52211328 = L.map(
#                 &quot;map_d208ea63e0c781c179c83c0e52211328&quot;,
#                 {
#                     center: [41.8781, -87.6298],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_e4cc21abddb75e2caaded734ad9bd07e = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_e4cc21abddb75e2caaded734ad9bd07e.addTo(map_d208ea63e0c781c179c83c0e52211328);
#
#
#             var choropleth_9e97805160f7f4d500ab9211bb8b8528 = L.featureGroup(
#                 {}
#             );
#
#
#         function geo_json_59cda8a2e35bff4f9c2e1b68f32f5edf_styler(feature) {
#             switch(feature.properties.h3_res_8_dropoff) {
#                 case &quot;8826641915fffff&quot;: case &quot;8826641b23fffff&quot;: case &quot;882664520bfffff&quot;: case &quot;8826645213fffff&quot;: case &quot;8826645219fffff&quot;: case &quot;8826645251fffff&quot;: case &quot;8826645253fffff&quot;: case &quot;8826645259fffff&quot;: case &quot;88266452c1fffff&quot;: case &quot;8826645613fffff&quot;: case &quot;8826645625fffff&quot;: case &quot;8826645629fffff&quot;: case &quot;882664562dfffff&quot;: case &quot;8826645637fffff&quot;: case &quot;8826645639fffff&quot;: case &quot;8826645649fffff&quot;: case &quot;8826645701fffff&quot;: case &quot;882664c843fffff&quot;: case &quot;882664c85dfffff&quot;: case &quot;882664c865fffff&quot;: case &quot;882664c8c5fffff&quot;: case &quot;882664cb3bfffff&quot;: case &quot;882664cb55fffff&quot;: case &quot;882664cb5dfffff&quot;: case &quot;882664cc43fffff&quot;: case &quot;882664cc4bfffff&quot;: case &quot;882664cc69fffff&quot;: case &quot;882664cc8dfffff&quot;: case &quot;882664cc95fffff&quot;: case &quot;882664cca9fffff&quot;: case &quot;882664ccebfffff&quot;: case &quot;882664ccedfffff&quot;: case &quot;882664cd05fffff&quot;: case &quot;882664cd25fffff&quot;: case &quot;882664cd2dfffff&quot;: case &quot;882664cd4bfffff&quot;: case &quot;882664cd83fffff&quot;: case &quot;882664cd8dfffff&quot;: case &quot;882664cd93fffff&quot;: case &quot;882664cdb1fffff&quot;: case &quot;882664cdbbfffff&quot;: case &quot;882664cde7fffff&quot;: case &quot;882664cdebfffff&quot;: case &quot;882664ce27fffff&quot;: case &quot;882664ceb1fffff&quot;: case &quot;882664ceb5fffff&quot;: case &quot;882664d833fffff&quot;: case &quot;882664d8edfffff&quot;: case &quot;8827593433fffff&quot;: case &quot;88275934edfffff&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#7fcdbb&quot;, &quot;fillOpacity&quot;: 0.7, &quot;opacity&quot;: 0.2, &quot;weight&quot;: 1};
#                 case &quot;882664191dfffff&quot;: case &quot;8826641963fffff&quot;: case &quot;8826645631fffff&quot;: case &quot;8826645707fffff&quot;: case &quot;882664cc65fffff&quot;: case &quot;882664ccc9fffff&quot;: case &quot;882664ccddfffff&quot;: case &quot;882664cd15fffff&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#41b6c4&quot;, &quot;fillOpacity&quot;: 0.7, &quot;opacity&quot;: 0.2, &quot;weight&quot;: 1};
#                 case &quot;8826641961fffff&quot;: case &quot;8826645215fffff&quot;: case &quot;88266452c9fffff&quot;: case &quot;88266452dbfffff&quot;: case &quot;882664562bfffff&quot;: case &quot;8826645641fffff&quot;: case &quot;8826645665fffff&quot;: case &quot;882664c10dfffff&quot;: case &quot;882664c121fffff&quot;: case &quot;882664c123fffff&quot;: case &quot;882664c125fffff&quot;: case &quot;882664c127fffff&quot;: case &quot;882664c129fffff&quot;: case &quot;882664c12bfffff&quot;: case &quot;882664c12dfffff&quot;: case &quot;882664c145fffff&quot;: case &quot;882664c147fffff&quot;: case &quot;882664c161fffff&quot;: case &quot;882664c163fffff&quot;: case &quot;882664c165fffff&quot;: case &quot;882664c167fffff&quot;: case &quot;882664c169fffff&quot;: case &quot;882664c16bfffff&quot;: case &quot;882664c16dfffff&quot;: case &quot;882664c8

# %%
create_choropleth(df,"h3_res_8_pickup","tips","Average tips")
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_8db02018a5270ea159c7b6ad311cbc84 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/d3/3.5.5/d3.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_8db02018a5270ea159c7b6ad311cbc84&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_8db02018a5270ea159c7b6ad311cbc84 = L.map(
#                 &quot;map_8db02018a5270ea159c7b6ad311cbc84&quot;,
#                 {
#                     center: [41.8781, -87.6298],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_9292a322b5bfcef70e2f870944258384 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_9292a322b5bfcef70e2f870944258384.addTo(map_8db02018a5270ea159c7b6ad311cbc84);
#
#
#             var choropleth_7602d5ee21ae6a2e7a0f0e66b13c58ab = L.featureGroup(
#                 {}
#             );
#
#
#         function geo_json_32a2d60bd8f7f1f35fcc9542e2baa2a3_styler(feature) {
#             switch(feature.properties.h3_res_8_pickup) {
#                 case &quot;8826641915fffff&quot;: case &quot;8826641961fffff&quot;: case &quot;8826641b23fffff&quot;: case &quot;8826645215fffff&quot;: case &quot;8826645251fffff&quot;: case &quot;88266452c9fffff&quot;: case &quot;88266452dbfffff&quot;: case &quot;8826645603fffff&quot;: case &quot;8826645613fffff&quot;: case &quot;882664562dfffff&quot;: case &quot;8826645639fffff&quot;: case &quot;8826645641fffff&quot;: case &quot;8826645701fffff&quot;: case &quot;882664c101fffff&quot;: case &quot;882664c103fffff&quot;: case &quot;882664c105fffff&quot;: case &quot;882664c107fffff&quot;: case &quot;882664c10dfffff&quot;: case &quot;882664c115fffff&quot;: case &quot;882664c117fffff&quot;: case &quot;882664c121fffff&quot;: case &quot;882664c123fffff&quot;: case &quot;882664c125fffff&quot;: case &quot;882664c127fffff&quot;: case &quot;882664c129fffff&quot;: case &quot;882664c12bfffff&quot;: case &quot;882664c12dfffff&quot;: case &quot;882664c131fffff&quot;: case &quot;882664c133fffff&quot;: case &quot;882664c135fffff&quot;: case &quot;882664c137fffff&quot;: case &quot;882664c139fffff&quot;: case &quot;882664c13bfffff&quot;: case &quot;882664c13dfffff&quot;: case &quot;882664c163fffff&quot;: case &quot;882664c165fffff&quot;: case &quot;882664c167fffff&quot;: case &quot;882664c169fffff&quot;: case &quot;882664c16dfffff&quot;: case &quot;882664c1a3fffff&quot;: case &quot;882664c1a7fffff&quot;: case &quot;882664c1abfffff&quot;: case &quot;882664c1adfffff&quot;: case &quot;882664c1e1fffff&quot;: case &quot;882664c1e5fffff&quot;: case &quot;882664c1e7fffff&quot;: case &quot;882664c1e9fffff&quot;: case &quot;882664c1ebfffff&quot;: case &quot;882664c1edfffff&quot;: case &quot;882664c80bfffff&quot;: case &quot;882664c81bfffff&quot;: case &quot;882664c831fffff&quot;: case &quot;882664c85bfffff&quot;: case &quot;882664c897fffff&quot;: case &quot;882664c8b3fffff&quot;: case &quot;882664c8cbfffff&quot;: case &quot;882664c8d7fffff&quot;: case &quot;882664ca03fffff&quot;: case &quot;882664ca0bfffff&quot;: case &quot;882664ca11fffff&quot;: case &quot;882664ca15fffff&quot;: case &quot;882664ca17fffff&quot;: case &quot;882664ca1bfffff&quot;: case &quot;882664ca29fffff&quot;: case &quot;882664ca3dfffff&quot;: case &quot;882664ca43fffff&quot;: case &quot;882664ca47fffff&quot;: case &quot;882664ca4bfffff&quot;: case &quot;882664ca4dfffff&quot;: case &quot;882664ca51fffff&quot;: case &quot;882664ca57fffff&quot;: case &quot;882664ca59fffff&quot;: case &quot;882664ca63fffff&quot;: case &quot;882664ca69fffff&quot;: case &quot;882664ca6bfffff&quot;: case &quot;882664ca81fffff&quot;: case &quot;882664ca83fffff&quot;: case &quot;882664ca85fffff&quot;: case &quot;882664ca89fffff&quot;: case &quot;882664ca8bfffff&quot;: case &quot;882664ca91fffff&quot;: case &quot;882664ca95fffff&quot;: case &quot;882664ca97fffff&quot;: case &quot;882664ca99fffff&quot;: case &quot;882664ca9bfffff&quot;: case &quot;882664ca9dfffff&quot;: case &quot;882664caabfffff&quot;: case &quot;882664caadfffff&quot;: case &quot;882664cab5fffff&quot;: case &quot;882664cabdfffff&quot;: case &quot;882664cac1fffff&quot;: case &quot;882664cac3fffff&quot;: case &quot;882664cac5fffff&quot;: case &quot;882664cac7fffff&quot;: case &quot;882664cacbfffff

# %% [markdown]
# # Heat Maps

# %%
tempdf = df.copy()

# %%
hourly = tempdf.groupby(df["trip_middle_timestamp"].dt.hour)["trip_seconds"].mean().reset_index()
weekdaily = tempdf.groupby(df["trip_middle_timestamp"].dt.weekday)["trip_seconds"].mean().reset_index()

# %%
# Neue Spalten für Stunde und Wochentag hinzufügen
tempdf['hour'] = df['trip_middle_timestamp'].dt.hour
tempdf['weekday'] = df['trip_middle_timestamp'].dt.day_name()

# %%
#NUMBER OF RIDES PER HOUR
pivot_table_trip_count = tempdf.pivot_table(index='weekday', columns='hour', values='trip_seconds', aggfunc='size')
pivot_table_trip_count = pivot_table_trip_count.reindex(['Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday', 'Saturday', 'Sunday'])

# Plot the heatmap
sns.heatmap(pivot_table_trip_count, cmap='viridis')
# Out:
# <Axes: xlabel='hour', ylabel='weekday'>

# %%
pivot_table_trip_seconds = tempdf.pivot_table(index='weekday', columns='hour', values='trip_seconds', aggfunc='mean')
pivot_table_trip_seconds = pivot_table_trip_seconds.reindex(['Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday', 'Saturday', 'Sunday'])
sns.heatmap(pivot_table_trip_seconds, cmap='viridis') #trip seconds
# Out:
# <Axes: xlabel='hour', ylabel='weekday'>

# %%
pivot_table_count = tempdf.pivot_table(index='weekday', columns='hour',values="tips",aggfunc='mean')
pivot_table_count = pivot_table_count.reindex(['Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday', 'Saturday', 'Sunday'])
sns.heatmap(pivot_table_count, cmap='viridis') #trip count
# Out:
# <Axes: xlabel='hour', ylabel='weekday'>

# %% [markdown]
# # Idle Time

# %%
df_sorted = df.sort_values(by=['taxi_id', 'trip_start_timestamp'])
df_sorted['idle_time'] = df_sorted.groupby('taxi_id')['trip_start_timestamp'].shift(-1) - df_sorted['trip_end_timestamp']
idledf = df_sorted.groupby('taxi_id')['idle_time'].mean().reset_index()
idledf
# Out:
#                                                 taxi_id  \
# 0     001330b81e23412049f9c3eff5b6e972a91afe59c9aa36...
# 1     0013da5489fe976daf4f4a7d246073ecf2caed9b12b3be...
# 2     0044e6c0d091476299b99345501f756b23632a96cbaf40...
# 3     00752524a4118a162dce62ff49c0eb0f79530d9e0ecb5a...
# 4     0083fcde0fb490b4ec424c63d1d750378f6ad11154d1d4...
# ...                                                 ...
# 5706  ffd70d111c7da2e5eff27ad900c8eb94d74fe286bb7aa5...
# 5707  ffda53354c610fd3af1aee46d723028a49014e35f7280c...
# 5708  ffe8d8153b8f68cd20871ae5710f9b799bcc517b40ece7...
# 5709  fff3279af11dfade5e308184a5cc6c1ca2d33764634d96...
# 5710  fff84aa08ac78890c6e7da64b817cbd9aad6a124104e09...
#
#                      idle_time
# 0    0 days 01:43:19.010568922
# 1    0 days 02:11:58.058628318
# 2    0 days 03:12:16.789431545
# 3    0 days 03:35:22.656597067
# 4    0 days 14:48:08.372093023
# ...                        ...
# 5706 0 days 02:49:41.571428571
# 5707 0 days 01:48:54.701834862
# 5708    0 days 02:19:10.400000
# 5709 0 days 03:12:44.963205233
# 5710          26 days 23:15:00
#
# [5711 rows x 2 columns]

# %% [markdown]
# I discontinued this analysis, because i figured that taxi_id represents a unique vehicle rather than a unique taxi driver. Thus, there could be multiple drivers operating one taxi over the course of the year.

# %% [markdown]
# # Correlation grouped by hour

# %%
corrdf = df.copy()

# %%
corrdf['date_hour'] = corrdf['trip_middle_timestamp'].dt.floor('h')
hourly_rides = corrdf.groupby('date_hour').size().reset_index(name='num_rides')
hourly_precipitation = corrdf.groupby('date_hour')['precipitation'].mean().reset_index()
hourly_temperature = corrdf.groupby('date_hour')['temperature'].mean().reset_index()
hourly_price_per_mile = corrdf.groupby('date_hour')['price_per_mile'].mean().reset_index()
hourly_trip_total = corrdf.groupby('date_hour')['trip_total'].mean().reset_index()
# Merge the DataFrames
hourly_data = pd.merge(hourly_rides, hourly_precipitation, on='date_hour')
hourly_data = pd.merge(hourly_data, hourly_temperature, on='date_hour')
hourly_data = pd.merge(hourly_data, hourly_price_per_mile, on='date_hour')
hourly_data = pd.merge(hourly_data, hourly_trip_total, on='date_hour')
hourly_data['hour'] = hourly_data['date_hour'].dt.hour
hourly_data["weekend"] = pd.DatetimeIndex(hourly_data['date_hour']).dayofweek >= 5

# %%
rides_precip_nonzero = hourly_data[hourly_data["precipitation"] > 0]["num_rides"].mean()
rides_precip_zero = hourly_data[hourly_data["precipitation"] == 0]["num_rides"].mean()

plot_data = pd.DataFrame({
    'Condition': ['Precipitation > 0', 'Precipitation = 0'],
    'Number of Rides': [rides_precip_nonzero, rides_precip_zero]
})

bar_plot = plt.bar(plot_data['Condition'], plot_data['Number of Rides'], color=['red', 'blue'])

for bar in bar_plot:
    yval = bar.get_height()
    plt.text(bar.get_x() + bar.get_width()/2, yval, int(yval), ha='center', va='bottom', fontsize=12)

plt.ylabel('Average number of Rides per hour')
plt.title('Number of Taxi Rides with Precipitation > 0 vs. Precipitation = 0')
# Out:
# Text(0.5, 1.0, 'Number of Taxi Rides with Precipitation > 0 vs. Precipitation = 0')

# %% [markdown]
# It should be noted that it rains a lot more at night where less rides occur. This plot shows that:

# %%
hourly_precipitation = hourly_data.groupby('hour')['precipitation'].mean().reset_index()
plt.figure(figsize=(12, 6))
sns.lineplot(x='hour', y='precipitation', data=hourly_precipitation, marker='o', color='blue')
plt.xlabel('Hour of the Day')
plt.ylabel('Average Precipitation')
plt.title('Average Precipitation per Hour of the Day Over the Course of the Year')
plt.grid(True)

# %% [markdown]
# Thus, I created a plot that also incorporates the usual average per hour as a baseline:

# %%
hourly_num_rides_no_rain = hourly_data[hourly_data["precipitation"]==0].groupby('hour')['num_rides'].mean().reset_index()
hourly_num_rides_rain = hourly_data[hourly_data["precipitation"]>0].groupby('hour')['num_rides'].mean().reset_index()
plt.figure(figsize=(14, 7))
sns.lineplot(x='hour', y='num_rides', data=hourly_num_rides_no_rain, label='No Precipitation', marker='o', color='green')
sns.lineplot(x='hour', y='num_rides', data=hourly_num_rides_rain, label='With Precipitation', marker='o', color='red')

plt.xlabel('Hour of the Day')
plt.ylabel('Average Number of Rides')
plt.title('Average Number of Taxi Rides per Hour of the Day')
plt.legend()
plt.grid(True)

# %% [markdown]
# It seems like rain could have a positive effects on rides at night, but a negative effect during the day. Effects could be marginal.

# %%
from sklearn.preprocessing import PolynomialFeatures
from sklearn.linear_model import LinearRegression
# Extract temperature and number of rides
X = hourly_data['temperature'].values.reshape(-1, 1)
y = hourly_data['num_rides'].values

# Create polynomial features
poly = PolynomialFeatures(degree=3)  
X_poly = poly.fit_transform(X)

# Fit the polynomial regression model
model = LinearRegression()
model.fit(X_poly, y)

# Predict values
y_poly_pred = model.predict(X_poly)

# Add predictions to the DataFrame for plotting
hourly_data['num_rides_poly_pred'] = y_poly_pred

# %%
plt.figure(figsize=(10, 6))
sns.scatterplot(x='temperature', y='num_rides', data=hourly_data, alpha=0.5, label='Data')

# Sort the data for plotting the line
sorted_data = hourly_data.sort_values('temperature')
plt.plot(sorted_data['temperature'], sorted_data['num_rides_poly_pred'], color='red', label='Polynomial Fit')

plt.title('Hourly Taxi Rides vs. Temperature with Polynomial Fit')
plt.xlabel('Average Hourly Temperature')
plt.ylabel('Number of Taxi Rides')
plt.legend()
plt.show()

# %%
fig, ax1 = plt.subplots(figsize=(14, 7))

# Plot number of rides
color = 'tab:blue'
ax1.set_xlabel('Hour of Day')
ax1.set_ylabel('Number of Rides', color=color)
line1 = sns.lineplot(x='hour', y='num_rides', data=hourly_data, ax=ax1, color=color, label='Number of Rides')
ax1.tick_params(axis='y', labelcolor=color)

# Plot price per mile
ax2 = ax1.twinx()
color = 'tab:red'
ax2.set_ylabel('Price per Mile', color=color)
line2 = sns.lineplot(x='hour', y='price_per_mile', data=hourly_data, ax=ax2, color=color, label='Price per Mile')
ax2.tick_params(axis='y', labelcolor=color)

# Add title and show plot
plt.title('24-Hour Visualization of Number of Rides and Price per Mile')

# Combine legends
lines, labels = ax1.get_legend_handles_labels()
lines2, labels2 = ax2.get_legend_handles_labels()
ax1.legend(lines + lines2, labels + labels2, loc='upper left')

plt.show()

# %%
sns.regplot(x='trip_seconds', y='tips', data=df.sample(10000), scatter_kws={'s':50, 'alpha':0.6}, line_kws={'color':'red'})
plt.title('Correlation between Trip Seconds and Tips')
plt.xlabel('Trip Seconds')
plt.ylabel('Tips')
plt.grid(True)

# %% [markdown]
# # Temporal Analysis

# %%
temp = df['trip_middle_timestamp'].dt.to_period('D')
daily_counts = temp.value_counts().sort_index()
daily_counts_rolling = daily_counts.rolling(window=7).mean()

daily_counts.plot(label='Daily Counts', alpha=0.15)
daily_counts_rolling.plot(label='Rolling Average (1 Week)', linestyle='--')
plt.title('Number of Rides with Rolling Average')
plt.xlabel('Day')
plt.ylabel('Number of Rides')
plt.legend()
plt.grid(True)

# %%
daily_trip_seconds = df.groupby(df['trip_middle_timestamp'].dt.to_period('D'))['trip_seconds'].mean().sort_index()
daily_trip_seconds_rolling = daily_trip_seconds.rolling(window=7).mean()

daily_trip_seconds.plot(label='Daily Average Trip Seconds', alpha=0.15)
daily_trip_seconds_rolling.plot(label='Rolling Average (1 Week)', linestyle='--')
plt.title('Average Trip Duration per Day with Rolling Average')
plt.xlabel('Day')
plt.ylabel('Total Trip Duration (seconds)')
plt.legend()
plt.grid(True)

# %%
daily_trip_miles = df.groupby(df['trip_middle_timestamp'].dt.to_period('D'))['trip_miles'].mean().sort_index()
daily_trip_miles_rolling = daily_trip_miles.rolling(window=7).mean()

daily_trip_miles.plot(label='Daily Average Trip Miles', alpha=0.15)
daily_trip_miles.plot(label='Rolling Average (1 Week)', linestyle='--')
plt.title('Average Trip Miles per Day with Rolling Average')
plt.xlabel('Day')
plt.ylabel('Total Trip Miles')
plt.legend()
plt.grid(True)

# %% [markdown]
# # Payment Type

# %%
payment_counts = df['payment_type'].value_counts().reset_index()
payment_counts.columns = ['payment_type', 'count']

# %%
payment_counts
# Out:
#   payment_type    count
# 0  Credit Card  7339690
# 1         Cash  7017183
# 2       Mobile   105563
# 3       Prcard    43971
# 4      Unknown    25556
# 5    No Charge    22187
# 6      Dispute     3361
# 7        Pcard     2649
# 8        Split     1271
# 9      Prepaid      597

# %%
plt.figure(figsize=(10, 6))
barplot = sns.barplot(x='payment_type', y='count', data=payment_counts, palette='viridis')

# Add annotations without decimal places
for bar in barplot.patches:
    height = bar.get_height()
    barplot.annotate(f'{int(height)}', 
                     (bar.get_x() + bar.get_width() / 2, 
                      height), ha='center', va='center',
                     size=12, xytext=(0, 8),
                     textcoords='offset points')

plt.xlabel('Payment Type')
plt.ylabel('Number of Rides')
plt.title('Number of Rides per Payment Type')
# Out:
# C:\Users\marlxn\AppData\Local\Temp\ipykernel_10836\366437917.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   barplot = sns.barplot(x='payment_type', y='count', data=payment_counts, palette='viridis')
# Text(0.5, 1.0, 'Number of Rides per Payment Type')

# %%
df['hour'] = df['trip_middle_timestamp'].dt.hour
hourly_payment_counts = df.groupby(['hour', 'payment_type']).size().reset_index(name='count')
total_counts_per_hour = hourly_payment_counts.groupby('hour')['count'].sum().reset_index(name='total_count')
hourly_payment_counts = pd.merge(hourly_payment_counts, total_counts_per_hour, on='hour')
hourly_payment_counts['percentage'] = (hourly_payment_counts['count'] / hourly_payment_counts['total_count']) * 100
pivot_data = hourly_payment_counts.pivot(index='hour', columns='payment_type', values='percentage').fillna(0)
pivot_data = pivot_data.reset_index()

plt.figure(figsize=(14, 7))

for payment_type in pivot_data.columns[1:]:
    plt.plot(pivot_data['hour'], pivot_data[payment_type], label=payment_type)

plt.xlabel('Hour of Day')
plt.ylabel('Percentage of Rides')
plt.title('Percentage Distribution of Payment Types by Hour of Day (Yearly Average)')
plt.legend(title='Payment Type')
plt.grid(True)
# Out:
# C:\Users\marlxn\AppData\Local\Temp\ipykernel_10836\1553735075.py:2: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   hourly_payment_counts = df.groupby(['hour', 'payment_type']).size().reset_index(name='count')
