# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Imports-and-Load-Data" data-toc-modified-id="Imports-and-Load-Data-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Imports and Load Data</a></span></li><li><span><a href="#Inspect-Meta-Data" data-toc-modified-id="Inspect-Meta-Data-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Inspect Meta Data</a></span><ul class="toc-item"><li><span><a href="#Weather_data_raw" data-toc-modified-id="Weather_data_raw-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>Weather_data_raw</a></span></li><li><span><a href="#Trip-Data-Raw" data-toc-modified-id="Trip-Data-Raw-2.2"><span class="toc-item-num">2.2&nbsp;&nbsp;</span>Trip Data Raw</a></span></li></ul></li><li><span><a href="#Prepare-Weather-Data,-POI-Data-and-supplemental-Data" data-toc-modified-id="Prepare-Weather-Data,-POI-Data-and-supplemental-Data-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Prepare Weather Data, POI Data and supplemental Data</a></span><ul class="toc-item"><li><span><a href="#Prepare-Weather-Data" data-toc-modified-id="Prepare-Weather-Data-3.1"><span class="toc-item-num">3.1&nbsp;&nbsp;</span>Prepare Weather Data</a></span><ul class="toc-item"><li><span><a href="#Select-relevant-columns" data-toc-modified-id="Select-relevant-columns-3.1.1"><span class="toc-item-num">3.1.1&nbsp;&nbsp;</span>Select relevant columns</a></span></li><li><span><a href="#Unpack-/-Format-Columns" data-toc-modified-id="Unpack-/-Format-Columns-3.1.2"><span class="toc-item-num">3.1.2&nbsp;&nbsp;</span>Unpack / Format Columns</a></span></li><li><span><a href="#Check-for-Outliers-/-Validity" data-toc-modified-id="Check-for-Outliers-/-Validity-3.1.3"><span class="toc-item-num">3.1.3&nbsp;&nbsp;</span>Check for Outliers / Validity</a></span></li><li><span><a href="#Visualize-Data" data-toc-modified-id="Visualize-Data-3.1.4"><span class="toc-item-num">3.1.4&nbsp;&nbsp;</span>Visualize Data</a></span></li></ul></li><li><span><a href="#Prepare-POI-Data" data-toc-modified-id="Prepare-POI-Data-3.2"><span class="toc-item-num">3.2&nbsp;&nbsp;</span>Prepare POI Data</a></span></li><li><span><a href="#Prepare-Supplemental-Data" data-toc-modified-id="Prepare-Supplemental-Data-3.3"><span class="toc-item-num">3.3&nbsp;&nbsp;</span>Prepare Supplemental Data</a></span><ul class="toc-item"><li><span><a href="#Prepare-baseball-data" data-toc-modified-id="Prepare-baseball-data-3.3.1"><span class="toc-item-num">3.3.1&nbsp;&nbsp;</span>Prepare baseball data</a></span></li></ul></li></ul></li><li><span><a href="#Prepare-Trip-Data" data-toc-modified-id="Prepare-Trip-Data-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Prepare Trip Data</a></span><ul class="toc-item"><li><span><a href="#Prepare-spatial-Columns" data-toc-modified-id="Prepare-spatial-Columns-4.1"><span class="toc-item-num">4.1&nbsp;&nbsp;</span>Prepare spatial Columns</a></span><ul class="toc-item"><li><span><a href="#Check-granularity" data-toc-modified-id="Check-granularity-4.1.1"><span class="toc-item-num">4.1.1&nbsp;&nbsp;</span>Check granularity</a></span></li><li><span><a href="#Check-for-missing-data" data-toc-modified-id="Check-for-missing-data-4.1.2"><span class="toc-item-num">4.1.2&nbsp;&nbsp;</span>Check for missing data</a></span></li><li><span><a href="#Convert-to-geopandas-column" data-toc-modified-id="Convert-to-geopandas-column-4.1.3"><span class="toc-item-num">4.1.3&nbsp;&nbsp;</span>Convert to geopandas column</a></span></li><li><span><a href="#Create-H3-discretization" data-toc-modified-id="Create-H3-discretization-4.1.4"><span class="toc-item-num">4.1.4&nbsp;&nbsp;</span>Create H3 discretization</a></span></li><li><span><a href="#Visualize-Data" data-toc-modified-id="Visualize-Data-4.1.5"><span class="toc-item-num">4.1.5&nbsp;&nbsp;</span>Visualize Data</a></span></li></ul></li><li><span><a href="#Check-for-duplicates" data-toc-modified-id="Check-for-duplicates-4.2"><span class="toc-item-num">4.2&nbsp;&nbsp;</span>Check for duplicates</a></span></li><li><span><a href="#Handling-missing-values" data-toc-modified-id="Handling-missing-values-4.3"><span class="toc-item-num">4.3&nbsp;&nbsp;</span>Handling missing values</a></span></li><li><span><a href="#Check-validity/-handle-outliers" data-toc-modified-id="Check-validity/-handle-outliers-4.4"><span class="toc-item-num">4.4&nbsp;&nbsp;</span>Check validity/ handle outliers</a></span></li><li><span><a href="#Join-Datasets" data-toc-modified-id="Join-Datasets-4.5"><span class="toc-item-num">4.5&nbsp;&nbsp;</span>Join Datasets</a></span></li></ul></li><li><span><a href="#Feature-Engineering-&amp;-Selection" data-toc-modified-id="Feature-Engineering-&amp;-Selection-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Feature Engineering &amp; Selection</a></span><ul class="toc-item"><li><span><a href="#Prediction-Task" data-toc-modified-id="Prediction-Task-5.1"><span class="toc-item-num">5.1&nbsp;&nbsp;</span>Prediction Task</a></span><ul class="toc-item"><li><span><a href="#Create-different-Time-Bins" data-toc-modified-id="Create-different-Time-Bins-5.1.1"><span class="toc-item-num">5.1.1&nbsp;&nbsp;</span>Create different Time Bins</a></span></li><li><span><a href="#Create-Cyclical-Time-Features-with-Sine-and-Cosine-Transformation" data-toc-modified-id="Create-Cyclical-Time-Features-with-Sine-and-Cosine-Transformation-5.1.2"><span class="toc-item-num">5.1.2&nbsp;&nbsp;</span>Create Cyclical Time Features with Sine and Cosine Transformation</a></span></li><li><span><a href="#Create-Lagged-Time-Features" data-toc-modified-id="Create-Lagged-Time-Features-5.1.3"><span class="toc-item-num">5.1.3&nbsp;&nbsp;</span>Create Lagged Time Features</a></span></li><li><span><a href="#Visualize-Relationship-between-Predictors-and-dependent-Variable" data-toc-modified-id="Visualize-Relationship-between-Predictors-and-dependent-Variable-5.1.4"><span class="toc-item-num">5.1.4&nbsp;&nbsp;</span>Visualize Relationship between Predictors and dependent Variable</a></span></li></ul></li></ul></li><li><span><a href="#Export-new-Datasets" data-toc-modified-id="Export-new-Datasets-6"><span class="toc-item-num">6&nbsp;&nbsp;</span>Export new Datasets</a></span></li></ul></div>

# %% [markdown]
# # Imports and Load Data

# %%
import ast
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
import json
import geopandas as gpd
from shapely.geometry import shape
from shapely.geometry import Point
from shapely.geometry import Polygon
import contextily as ctx
from h3 import h3
#import census

# %%
warnings.filterwarnings("ignore", category=FutureWarning)

# %%
trip_data_raw = pd.read_csv(
    r'../data/chicago_taxi_data.csv',
    index_col=None,
    nrows=300000,
    dtype={
        'payment_type': 'category',
        'company': 'category'
    },
    parse_dates=['trip_start_timestamp', 'trip_end_timestamp'])

# %%
weather_data_raw = pd.read_csv(r'../data/weather_raw.csv',
                               dtype={},
                               index_col=None)

# %% [markdown]
# # Inspect Meta Data

# %% [markdown]
# ## Weather_data_raw

# %%
weather_data_raw.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10452 entries, 0 to 10451
# Data columns (total 11 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   date         10452 non-null  object
#  1   Time         10452 non-null  object
#  2   Temperature  10452 non-null  object
#  3   Dew Point    10452 non-null  object
#  4   Humidity     10452 non-null  object
#  5   Wind         10452 non-null  object
#  6   Wind Speed   10452 non-null  object
#  7   Wind Gust    10452 non-null  object
#  8   Pressure     10452 non-null  object
#  9   Precip.      10452 non-null  object
#  10  Condition    10452 non-null  object
# dtypes: object(11)
# memory usage: 898.3+ KB

# %%
weather_data_raw.describe()
# Out:
#               date     Time Temperature Dew Point Humidity   Wind Wind Speed  \
# count        10452    10452       10452     10452    10452  10452      10452
# unique         365      959         106        96       85     18         29
# top     2018-06-10  7:53 PM       34 °F     65 °F     93 %    SSW      9 mph
# freq            51      366         293       256      474    923       1000
#
#        Wind Gust  Pressure Precip. Condition
# count      10452     10452   10452     10452
# unique        32       144      10        39
# top        0 mph  29.27 in  0.0 in    Cloudy
# freq        8781       441   10056      2626

# %%
weather_data_raw.head(5)
# Out:
#          date     Time Temperature Dew Point Humidity Wind Wind Speed  \
# 0  2018-01-01  1:53 AM       -1 °F    -12 °F     60 %  WNW      8 mph
# 1  2018-01-01  2:53 AM       -2 °F    -13 °F     60 %  WNW     10 mph
# 2  2018-01-01  3:53 AM       -3 °F    -14 °F     59 %   NW     12 mph
# 3  2018-01-01  4:53 AM       -4 °F    -15 °F     59 %   NW     12 mph
# 4  2018-01-01  5:53 AM       -5 °F    -15 °F     62 %  WNW      9 mph
#
#   Wind Gust  Pressure Precip.      Condition
# 0     0 mph  29.96 in  0.0 in           Fair
# 1     0 mph  29.98 in  0.0 in           Fair
# 2     0 mph  29.98 in  0.0 in           Fair
# 3     0 mph  29.98 in  0.0 in           Fair
# 4     0 mph  29.98 in  0.0 in  Partly Cloudy

# %% [markdown]
# ## Trip Data Raw

# %%
trip_data_raw.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 300000 entries, 0 to 299999
# Data columns (total 23 columns):
#  #   Column                      Non-Null Count   Dtype
# ---  ------                      --------------   -----
#  0   trip_id                     300000 non-null  object
#  1   taxi_id                     299992 non-null  object
#  2   trip_start_timestamp        300000 non-null  datetime64[ns]
#  3   trip_end_timestamp          299998 non-null  datetime64[ns]
#  4   trip_seconds                299987 non-null  float64
#  5   trip_miles                  299990 non-null  float64
#  6   pickup_census_tract         182099 non-null  float64
#  7   dropoff_census_tract        180946 non-null  float64
#  8   pickup_community_area       271120 non-null  float64
#  9   dropoff_community_area      264651 non-null  float64
#  10  fare                        299984 non-null  float64
#  11  tips                        299984 non-null  float64
#  12  tolls                       212493 non-null  float64
#  13  extras                      299984 non-null  float64
#  14  trip_total                  299984 non-null  float64
#  15  payment_type                300000 non-null  category
#  16  company                     300000 non-null  category
#  17  pickup_centroid_latitude    271334 non-null  float64
#  18  pickup_centroid_longitude   271334 non-null  float64
#  19  pickup_centroid_location    271334 non-null  object
#  20  dropoff_centroid_latitude   265461 non-null  float64
#  21  dropoff_centroid_longitude  265461 non-null  float64
#  22  dropoff_centroid_location   265461 non-null  object
# dtypes: category(2), datetime64[ns](2), float64(15), object(4)
# memory usage: 48.6+ MB

# %%
trip_data_raw.describe()
# Out:
#         trip_seconds     trip_miles  pickup_census_tract  \
# count  299987.000000  299990.000000         1.820990e+05
# mean      681.700507       3.298192         1.703138e+10
# std      1223.341196       5.497132         3.405399e+05
# min         0.000000       0.000000         1.703101e+10
# 25%       300.000000       0.600000         1.703108e+10
# 50%       480.000000       1.220000         1.703128e+10
# 75%       836.000000       3.100000         1.703184e+10
# max     86340.000000     783.700000         1.703198e+10
#
#        dropoff_census_tract  pickup_community_area  dropoff_community_area  \
# count          1.809460e+05          271120.000000           264651.000000
# mean           1.703135e+10              24.623768               21.305867
# std            3.265682e+05              20.413084               17.365021
# min            1.703101e+10               1.000000                1.000000
# 25%            1.703108e+10               8.000000                8.000000
# 50%            1.703128e+10              28.000000               16.000000
# 75%            1.703183e+10              32.000000               32.000000
# max            1.703198e+10              77.000000               77.000000
#
#                 fare           tips          tolls         extras  \
# count  299984.000000  299984.000000  212493.000000  299984.000000
# mean       12.423408       1.294975       0.004931       0.964671
# std        51.797434       2.694211       0.446381       4.224788
# min         0.000000       0.000000       0.000000       0.000000
# 25%         5.500000       0.000000       0.000000       0.000000
# 50%         7.500000       0.000000       0.000000       0.000000
# 75%        12.250000       2.000000       0.000000       1.000000
# max      8000.900000     500.000000      75.000000    1414.120000
#
#           trip_total  pickup_centroid_latitude  pickup_centroid_longitude  \
# count  299984.000000             271334.000000              271334.000000
# mean       14.782678                 41.901167                 -87.662549
# std        52.880095                  0.040519                   0.077099
# min         0.000000                 41.660136                 -87.913625
# 25%         6.500000                 41.880994                 -87.655998
# 50%         9.000000                 41.892073                 -87.632746
# 75%        14.160000                 41.904935                 -87.626211
# max      8050.970000                 42.015934                 -87.534903
#
#        dropoff_centroid_latitude  dropoff_centroid_longitude
# count              265461.000000               265461.000000
# mean                   41.901070                  -87.652773
# std                     0.039415                    0.055798
# min                    41.660136                  -87.913625
# 25%                    41.880994                  -87.655998
# 50%                    41.892508                  -87.633308
# 75%                    41.914616                  -87.626211
# max                    42.021224                  -87.534903

# %%
trip_data_raw.head(20)
# Out:
#                                      trip_id  \
# 0   d7bf7332e89c6597d682495ac78a325c2ed4183f
# 1   c8769473b60b18f700afce0f812f6d80c3616ca7
# 2   c52d1cd141c3036d091ed85cbf7a973cc5c1243e
# 3   b5714d1d2118642f789ab0fec542f597f986c251
# 4   0352e306e7cc33a455c3be20764ad2ce9881216a
# 5   594e15b562a96bd7cafac7211fb71ff4331ee803
# 6   2896540c849ebc75c05af74af4b969759eaa5fa3
# 7   71b0b8528bb56e921997c6de6190257fe2e58dcd
# 8   047773cc8210996a8f88ad023c79c86bba5423de
# 9   80447e42e7ad6f32607bdcbba79725b3ea8bc094
# 10  a6673cb2888d07e963a35fedd3a635ac1b11c3d4
# 11  0a0a2ca50df85134ce34f0c2c7bda6e78ca2a52c
# 12  7c46253c55f14a47b0bdd41baa1abc0366d64c58
# 13  ac1fae1544d7804f13fbf657cb058ba91a983fea
# 14  b7e939ebeb25eee245afd346ff63adeb0139e6d7
# 15  29f96067e9339e477e983efddd6395a2a8557c45
# 16  967a2dad921818b54a19b27a9c67310f7cfb9f2c
# 17  a6ecf116e5ed732519617bf003100af806fa1f02
# 18  e4bcdde34928852b0d8ed4641f4c0533e06a29ab
# 19  649cae1facf2431d6e5578fec8cadfef46d79841
#
#                                               taxi_id trip_start_timestamp  \
# 0   d0653a3c1a990641559a9e6e7c0e07db3765fe11e48ad7...  2018-01-01 00:15:00
# 1   21c5d83c2cb73035c6c4d35da452ff1714aff86f5efb32...  2018-01-01 00:15:00
# 2   a6c3cb7ab4c037a7db9e2fd3513f28e0ff17c8547a70bd...  2018-01-01 00:15:00
# 3   d8238dd38b47fc0268e0bd92bba094676752dfefeafea9...  2018-01-01 00:15:00
# 4   7698f29134c0f429f821af4e89a8f769b85e376bd37b3c...  2018-01-01 00:15:00
# 5   45ae9d400abb9327b717e4d8849843ad78e40d7a72e324...  2018-01-01 00:15:00
# 6   3fb54b9070b703bd28358e704311d7fe8afb6950881654...  2018-01-01 00:15:00
# 7   0c722e1c967f929866e205cde7aefefae970c66351c0db...  2018-01-01 00:15:00
# 8   9454a3cb5d7e8ef84ca9bfff9f1a5d235021fef66b41a8...  2018-01-01 00:15:00
# 9   5e2cdbf8e29532911397d269fc7777dbe01700c6dbc517...  2018-01-01 00:15:00
# 10  21c5d83c2cb73035c6c4d35da452ff1714aff86f5efb32...  2018-01-01 00:15:00
# 11  bbe793119144e0bd97a4268af2a28ed0f3dad49545592c...  2018-01-01 00:15:00
# 12  99ab5248605aa4afb82e6be7d50d531fd8e423980159bb...  2018-01-01 00:15:00
# 13  847cf962bd6f62040673e6c24c24940aeb2d7fdaa54677...  2018-01-01 00:15:00
# 14  efd204f38a83a59df5bf4a1fe004aa291183e235ee40ee...  2018-01-01 00:15:00
# 15  92725f67f872c1d48d77ffa906f837c6a5f20f5a597a8d...  2018-01-01 00:15:00
# 16  609fa4bfe241aacb61e59c5b52abcbbd467b8e71d53dd9...  2018-01-01 00:15:00
# 17  1061d157b2a98a1b1e7871639b836de5fb521101d08d73...  2018-01-01 00:15:00
# 18  c38a211cb84a44a24e959493d5842a48dd150b1e947b30...  2018-01-01 00:15:00
# 19  15dd49f5b45c96f8f6dd62e5a50224a9b8abd8bc891648...  2018-01-01 00:15:00
#
#     trip_end_timestamp  trip_seconds  trip_miles  pickup_census_tract  \
# 0  2018-01-01 00:30:00        1080.0         3.7                  NaN
# 1  2018-01-01 00:30:00         240.0         0.3                  NaN
# 2  2018-01-01 00:15:00          60.0         0.4                  NaN
# 3  2018-01-01 00:30:00         840.0         2.7                  NaN
# 4  2018-01-01 00:15:00           0.0         0.0                  NaN
# 5  2018-01-01 00:30:00         720.0         6.5                  NaN
# 6  2018-01-01 00:30:00         660.0         0.5                  NaN
# 7  2018-01-01 00:15:00           0.0         0.0                  NaN
# 8  2018-01-01 00:15:00           0.0         0.0                  NaN
# 9  2018-01-01 00:15:00         480.0         0.2                  NaN
# 10 2018-01-01 00:15:00         420.0         0.7                  NaN
# 11 2018-01-01 00:15:00         180.0         0.0         1.703108e+10
# 12 2018-01-01 00:15:00         120.0         0.7                  NaN
# 13 2018-01-01 00:30:00         960.0         2.6         1.703107e+10
# 14 2018-01-01 00:30:00        1260.0         0.0         1.703108e+10
# 15 2018-01-01 00:30:00         660.0         0.0         1.703108e+10
# 16 2018-01-01 00:30:00         300.0         0.9         1.703108e+10
# 17 2018-01-01 00:30:00         180.0         0.8                  NaN
# 18 2018-01-01 00:30:00        1320.0         0.2         1.703107e+10
# 19 2018-01-01 00:30:00         900.0         0.9         1.703108e+10
#
#     dropoff_census_tract  pickup_community_area  dropoff_community_area  ...  \
# 0                    NaN                    NaN                     NaN  ...
# 1                    NaN                    NaN                     NaN  ...
# 2                    NaN                    NaN                     NaN  ...
# 3                    NaN                    NaN                     NaN  ...
# 4                    NaN                    NaN                     NaN  ...
# 5                    NaN                    NaN                     NaN  ...
# 6                    NaN                    NaN                     NaN  ...
# 7                    NaN                    NaN                     NaN  ...
# 8                    NaN                    NaN                     NaN  ...
# 9                    NaN                    NaN                     NaN  ...
# 10                   NaN                    NaN                     NaN  ...
# 11          1.703132e+10                    8.0                    32.0  ...
# 12                   NaN                    5.0                     5.0  ...
# 13          1.703108e+10                    7.0                     8.0  ...
# 14          1.703108e+10                    8.0                     8.0  ...
# 15          1.703124e+10                    8.0                    24.0  ...
# 16          1.703108e+10                    8.0                     8.0  ...
# 17                   NaN                    6.0                     6.0  ...
# 18          1.703184e+10                    7.0                    32.0  ...
# 19          1.703108e+10                    8.0                     8.0  ...
#
#     extras  trip_total  payment_type                            company  \
# 0      0.0       17.55   Credit Card            Choice Taxi Association
# 1      1.0        5.50          Cash            Choice Taxi Association
# 2      0.0        3.75          Cash          Dispatch Taxi Affiliation
# 3      1.0       11.50          Cash          Star North Management LLC
# 4      0.0       14.50   Credit Card              Suburban Dispatch LLC
# 5      4.0       22.00          Cash          Dispatch Taxi Affiliation
# 6      0.0        7.25          Cash              KOAM Taxi Association
# 7      0.0       44.00   Credit Card              Suburban Dispatch LLC
# 8      0.0       11.00   Credit Card              Suburban Dispatch LLC
# 9      0.0        5.75          Cash            Choice Taxi Association
# 10     1.0        9.00   Credit Card            Choice Taxi Association
# 11     1.0        7.00   Credit Card  Blue Ribbon Taxi Association Inc.
# 12     2.0        6.75          Cash          Star North Management LLC
# 13     0.0       11.00          Cash          Taxi Affiliation Services
# 14     2.5       13.00          Cash          Star North Management LLC
# 15     1.5       12.50          Cash  Blue Ribbon Taxi Association Inc.
# 16     1.5        7.00          Cash            Choice Taxi Association
# 17     2.0        7.00          Cash          Taxi Affiliation Services
# 18     1.5       16.75          Cash          Taxi Affiliation Services
# 19     1.0        9.75          Cash            Choice Taxi Association
#
#     pickup_centroid_latitude pickup_centroid_longitude  \
# 0                        NaN                       NaN
# 1                        NaN                       NaN
# 2                        NaN                       NaN
# 3                        NaN                       NaN
# 4                        NaN                       NaN
# 5                        NaN                       NaN
# 6                        NaN                       NaN
# 7                        NaN                       NaN
# 8                        NaN                       NaN
# 9                        NaN                       NaN
# 10                       NaN                       NaN
# 11                 41.892508                -87.626215
# 12                 41.947792                -87.683835
# 13                 41.914616                -87.631717
# 14                 41.892073                -87.628874
# 15                 41.907492                -87.635760
# 16                 41.892042                -87.631864
# 17                 41.944227                -87.655998
# 18                 41.921855                -87.646211
# 19                 41.902788                -87.626146
#
#                              pickup_centroid_location  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11  {'type': 'Point', 'coordinates': [-87.62621490...
# 12  {'type': 'Point', 'coordinates': [-87.68383494...
# 13  {'type': 'Point', 'coordinates': [-87.63171736...
# 14  {'type': 'Point', 'coordinates': [-87.62887415...
# 15  {'type': 'Point', 'coordinates': [-87.63576009...
# 16  {'type': 'Point', 'coordinates': [-87.63186394...
# 17  {'type': 'Point', 'coordinates': [-87.65599818...
# 18  {'type': 'Point', 'coordinates': [-87.64621097...
# 19  {'type': 'Point', 'coordinates': [-87.62614558...
#
#     dropoff_centroid_latitude  dropoff_centroid_longitude  \
# 0                         NaN                         NaN
# 1                         NaN                         NaN
# 2                         NaN                         NaN
# 3                         NaN                         NaN
# 4                         NaN                         NaN
# 5                         NaN                         NaN
# 6                         NaN                         NaN
# 7                         NaN                         NaN
# 8                         NaN                         NaN
# 9                         NaN                         NaN
# 10                        NaN                         NaN
# 11                  41.884987                  -87.620993
# 12                  41.947792                  -87.683835
# 13                  41.907520                  -87.626659
# 14                  41.891972                  -87.612945
# 15                  41.899590                  -87.674719
# 16                  41.891972                  -87.612945
# 17                  41.944227                  -87.655998
# 18                  41.880994                  -87.632746
# 19                  41.892508                  -87.626215
#
#                             dropoff_centroid_location
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11  {'type': 'Point', 'coordinates': [-87.62099291...
# 12  {'type': 'Point', 'coordinates': [-87.68383494...
# 13  {'type': 'Point', 'coordinates': [-87.62665890...
# 14  {'type': 'Point', 'coordinates': [-87.61294541...
# 15  {'type': 'Point', 'coordinates': [-87.67471913...
# 16  {'type': 'Point', 'coordinates': [-87.61294541...
# 17  {'type': 'Point', 'coordinates': [-87.65599818...
# 18  {'type': 'Point', 'coordinates': [-87.63274648...
# 19  {'type': 'Point', 'coordinates': [-87.62621490...
#
# [20 rows x 23 columns]

# %% [markdown]
#    # Prepare Weather Data, POI Data and supplemental Data

# %% [markdown]
# ## Prepare Weather Data

# %% [markdown]
# * select relevant columns
# * unpack/format columns
# * check for outliers/ validity

# %% [markdown]
# ### Select relevant columns

# %%
print(weather_data_raw.columns)
# Out:
# Index(['date', 'Time', 'Temperature', 'Dew Point', 'Humidity', 'Wind',
#        'Wind Speed', 'Wind Gust', 'Pressure', 'Precip.', 'Condition'],
#       dtype='object')

# %%
weather_data_raw.drop(
    ['Dew Point', 'Humidity', 'Wind', 'Wind Gust', 'Pressure'],
    axis=1,
    inplace=True)

# %%
weather_data_raw.head(25)
# Problem row 23 should be 2018-01-02 -> lists first of the next day in table of the previous day
# Out:
#           date      Time Temperature Wind Speed Precip.      Condition
# 0   2018-01-01   1:53 AM       -1 °F      8 mph  0.0 in           Fair
# 1   2018-01-01   2:53 AM       -2 °F     10 mph  0.0 in           Fair
# 2   2018-01-01   3:53 AM       -3 °F     12 mph  0.0 in           Fair
# 3   2018-01-01   4:53 AM       -4 °F     12 mph  0.0 in           Fair
# 4   2018-01-01   5:53 AM       -5 °F      9 mph  0.0 in  Partly Cloudy
# 5   2018-01-01   6:53 AM       -6 °F     13 mph  0.0 in           Fair
# 6   2018-01-01   7:53 AM       -7 °F     10 mph  0.0 in           Fair
# 7   2018-01-01   8:53 AM       -7 °F      9 mph  0.0 in           Fair
# 8   2018-01-01   9:53 AM       -6 °F     10 mph  0.0 in           Fair
# 9   2018-01-01  10:53 AM       -4 °F     12 mph  0.0 in           Fair
# 10  2018-01-01  11:53 AM       -2 °F     10 mph  0.0 in           Fair
# 11  2018-01-01  12:53 PM        1 °F     10 mph  0.0 in           Fair
# 12  2018-01-01   1:53 PM        2 °F     12 mph  0.0 in           Fair
# 13  2018-01-01   2:53 PM        3 °F     12 mph  0.0 in           Fair
# 14  2018-01-01   3:53 PM        3 °F     13 mph  0.0 in           Fair
# 15  2018-01-01   4:53 PM        2 °F     12 mph  0.0 in           Fair
# 16  2018-01-01   5:53 PM        0 °F      9 mph  0.0 in           Fair
# 17  2018-01-01   6:53 PM       -1 °F     12 mph  0.0 in           Fair
# 18  2018-01-01   7:53 PM       -3 °F     12 mph  0.0 in           Fair
# 19  2018-01-01   8:53 PM       -4 °F     10 mph  0.0 in         Cloudy
# 20  2018-01-01   9:53 PM       -5 °F      9 mph  0.0 in         Cloudy
# 21  2018-01-01  10:53 PM       -5 °F      7 mph  0.0 in         Cloudy
# 22  2018-01-01  11:53 PM       -5 °F      9 mph  0.0 in         Cloudy
# 23  2018-01-01  12:53 AM       -5 °F      9 mph  0.0 in         Cloudy
# 24  2018-01-02   1:53 AM       -5 °F      8 mph  0.0 in         Cloudy

# %% [markdown]
# ### Unpack / Format Columns

# %%
def format_columns_weather(row):

    return pd.Series(data={
        'date': extract_time_weather(row['date'], row['Time']),
        'temperature': format_temperature(row['Temperature']),
        'wind_speed': format_wind(row['Wind Speed']),
        'condition': row['Condition'],
        'precipitation': format_precipitation(row['Precip.'])
    },
                     index=None)


def extract_time_weather(date_cell, Time_cell):

    date = pd.to_datetime(date_cell + "-" + Time_cell,
                          format='%Y-%m-%d-%I:%M %p')

    return date


def format_temperature(temp_cell):

    temp_cell = temp_cell.replace('°F', "")
    temp_cell = temp_cell.strip()

    return (int(temp_cell) - 32) * 5 / 9  # transform Fahrenheit into celsius


def format_wind(wind_cell):

    return int(wind_cell.replace("mph", "").strip())


def format_precipitation(precip_cell):
    return float(precip_cell.replace("in", "").strip())

# %%
weather_data = pd.DataFrame(weather_data_raw.apply(
    lambda row: format_columns_weather(row), axis=1),
                            index=None)

# %%
weather_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10452 entries, 0 to 10451
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   date           10452 non-null  datetime64[ns]
#  1   temperature    10452 non-null  float64
#  2   wind_speed     10452 non-null  int64
#  3   condition      10452 non-null  object
#  4   precipitation  10452 non-null  float64
# dtypes: datetime64[ns](1), float64(2), int64(1), object(1)
# memory usage: 408.4+ KB

# %%
weather_data.head(2)
# Out:
#                  date  temperature  wind_speed condition  precipitation
# 0 2018-01-01 01:53:00   -18.333333           8      Fair            0.0
# 1 2018-01-01 02:53:00   -18.888889          10      Fair            0.0

# %% [markdown]
# ### Check for Outliers / Validity

# %%
weather_data.describe()
# Out:
#         temperature    wind_speed  precipitation
# count  10452.000000  10452.000000   10452.000000
# mean      10.811806      9.826062       0.006764
# std       11.599960      5.101400       0.045327
# min      -22.777778      0.000000       0.000000
# 25%        1.111111      6.000000       0.000000
# 50%       10.000000      9.000000       0.000000
# 75%       21.111111     13.000000       0.000000
# max       35.555556     40.000000       1.100000

# %% [markdown]
# ### Visualize Data

# %%
figure, ax = plt.subplots(2, 1, figsize=(16, 16))
ax[0].grid(True, color='gray')
sns.lineplot(data=weather_data, x='date', y='temperature', ax=ax[0])
ax[0].set_xlabel('Date')
ax[0].set_ylabel('Temperature (Celsius)')

visualize_precipitation = weather_data.set_index('date').resample('W').mean()

sns.barplot(data=visualize_precipitation,
            x=list(visualize_precipitation.index),
            y='precipitation')
ax[1].set_ylabel('Average Precipitation per Week')
ax[1].set_xlabel('Date')
ax[1].set_xticks(ax[1].get_xticks()[::4])
ax[1].set_xticklabels(list(visualize_precipitation.index[::4]), rotation=45)

plt.show()

# %%
visualize_precipitation.index.strftime('%Y-%m-%d')
# Out:
# Index(['2018-01-07', '2018-01-14', '2018-01-21', '2018-01-28', '2018-02-04',
#        '2018-02-11', '2018-02-18', '2018-02-25', '2018-03-04', '2018-03-11',
#        '2018-03-18', '2018-03-25', '2018-04-01', '2018-04-08', '2018-04-15',
#        '2018-04-22', '2018-04-29', '2018-05-06', '2018-05-13', '2018-05-20',
#        '2018-05-27', '2018-06-03', '2018-06-10', '2018-06-17', '2018-06-24',
#        '2018-07-01', '2018-07-08', '2018-07-15', '2018-07-22', '2018-07-29',
#        '2018-08-05', '2018-08-12', '2018-08-19', '2018-08-26', '2018-09-02',
#        '2018-09-09', '2018-09-16', '2018-09-23', '2018-09-30', '2018-10-07',
#        '2018-10-14', '2018-10-21', '2018-10-28', '2018-11-04', '2018-11-11',
#        '2018-11-18', '2018-11-25', '2018-12-02', '2018-12-09', '2018-12-16',
#        '2018-12-23', '2018-12-30', '2019-01-06'],
#       dtype='object', name='date')

# %% [markdown]
# ## Prepare POI Data

# %% [markdown]
# ## Prepare Supplemental Data

# %% [markdown]
# * select relevant columns
# * unpack/format columns
# * join datasets & create features from

# %% [markdown]
# ### Prepare baseball data

# %%
chicago_bulls_raw = pd.read_csv(r'../data/Chicago_Bulls.csv', index_col=None)

# %%
chicago_bulls_raw.head(5)
# Out:
#    G             Date Start (ET)  Unnamed: 3 Unnamed: 4 Unnamed: 5  \
# 0  1  Thu Oct 18 2018      8:00p         NaN  Box Score          @
# 1  2  Sat Oct 20 2018      8:00p         NaN  Box Score        NaN
# 2  3  Mon Oct 22 2018      8:30p         NaN  Box Score          @
# 3  4  Wed Oct 24 2018      8:00p         NaN  Box Score        NaN
# 4  5  Fri Oct 26 2018      7:00p         NaN  Box Score          @
#
#              Opponent Unnamed: 7 Unnamed: 8   Tm  Opp  W  L Streak Notes
# 0  Philadelphia 76ers          L        NaN  108  127  0  1    L 1   NaN
# 1     Detroit Pistons          L        NaN  116  118  0  2    L 2   NaN
# 2    Dallas Mavericks          L        NaN  109  115  0  3    L 3   NaN
# 3   Charlotte Hornets          W        NaN  112  110  1  3    W 1   NaN
# 4   Charlotte Hornets          L        NaN  106  135  1  4    L 1   NaN

# %%
chicago_bulls_raw = chicago_bulls_raw.loc[chicago_bulls_raw['Unnamed: 5'] ==
                                          '@']
chicago_bulls_raw.head(2)
# Out:
#    G             Date Start (ET)  Unnamed: 3 Unnamed: 4 Unnamed: 5  \
# 0  1  Thu Oct 18 2018      8:00p         NaN  Box Score          @
# 2  3  Mon Oct 22 2018      8:30p         NaN  Box Score          @
#
#              Opponent Unnamed: 7 Unnamed: 8   Tm  Opp  W  L Streak Notes
# 0  Philadelphia 76ers          L        NaN  108  127  0  1    L 1   NaN
# 2    Dallas Mavericks          L        NaN  109  115  0  3    L 3   NaN

# %%
def extract_date_baseball(row):
    date = pd.to_datetime(row['Date'] + ',' +
                          row['Start (ET)'].replace("p", "PM"),
                          format='%a %b %d %Y,%I:%M%p')
    return pd.Series(data={'date': date})

# %%
chicago_bulls = pd.DataFrame(
    chicago_bulls_raw.apply(lambda row: extract_date_baseball(row), axis=1))
chicago_bulls.head(1)
# Out:
#                  date
# 0 2018-10-18 20:00:00

# %% [markdown]
# # Prepare Trip Data

# %% [markdown]
# * decide which geographical column(s) for spatial analysis/ feature
# * handle missing values
# * check for outliers
# * check for data validity
# * prepare spatial data
# * normalize data
# * cut into taskspecific datasets & export new data

# %% [markdown]
# ## Prepare spatial Columns

# %% [markdown]
# **<font size=4>Pickup/Dropoff_census_tract</font>**
#
# **Definition of ChatGPT:** "A census tract is a geographic area defined by the United States Census Bureau for the purpose of taking the census. Census tracts are relatively small, permanent subdivisions of a county or equivalent entity that are updated by local participants prior to each decennial census as part of the Census Bureau's Participant Statistical Areas Program."
#
# * **Demographic Analysis:** Census tracts are often associated with specific demographic characteristics, such as income levels, population density, and racial composition. Analyzing taxi trip data in conjunction with census tract demographics can provide insights into the socioeconomic factors influencing travel patterns.
#
# * --> install CensusData package to obtain demographic data
#
# * --> demographic data interesting for prediction task? --> a lot of missing data compared to other spatial columns, so that other for prediction
#
# **<font size=4>Longitude/ Latitude Columns</font>**
#
# * containts the same data as the location columns but in more columns
# * --> are more efficient in storing
# * --> however, more missing values compared to the location column
# * --> discrepancy between location and longitude / latitude column
#      * --> maybe other granualrity?
#
# **<font size=4>Centroid Location Column</font>**
#
# * contains a point which consists for the longitude and latitude -> has the least missing values
# * -> candidate for prediciton/ cluster task?
#
#
# -> see if spatial data is on the same granularity: if yes fill missing values of the other coordinates

# %% [markdown]
# ### Check granularity

# %%
print(trip_data_raw['pickup_centroid_latitude'].nunique())
print(trip_data_raw['pickup_centroid_location'].nunique())
print(trip_data_raw['pickup_census_tract'].nunique())
# Out:
# 280
# 280
# 252

# %% [markdown]
# Census tract data seem to be of a finer grid than the rest of the data -> difficult to map from the locaton_data to the census tract data

# %% [markdown]
# ### Check for missing data

# %%
print(
    len(trip_data_raw.loc[
        ~pd.isna(trip_data_raw['pickup_centroid_latitude'])
        ^ ~pd.isna(trip_data_raw['pickup_centroid_longitude'])]),
    "number of columns were either pickup_centroid_latitude xor pickup_centroid_longitude is filled\n"
)
print(
    len(trip_data_raw.loc[
        ~pd.isna(trip_data_raw['pickup_centroid_latitude'])
        ^ ~pd.isna(trip_data_raw['pickup_centroid_location'])]),
    "number of columns were either pickup_centroid_latitude xor pickup_centroid_location is filled\n"
)
print(
    len(trip_data_raw.loc[
        ~pd.isna(trip_data_raw['pickup_centroid_latitude'])
        & ~pd.isna(trip_data_raw['pickup_centroid_location'])]),
    "number of columns were either pickup_centroid_latitude and pickup_centroid_longitude and pickup_centroid_location are filled\n"
)
print(
    len(trip_data_raw.loc[pd.isna(trip_data_raw['pickup_centroid_latitude'])
                          & ~pd.isna(trip_data_raw['pickup_census_tract'])]),
    "number of columns were pickup_centroid_latitude and pickup_centroid_longitude and pickup_centroid_location are not filled but census trackt\n"
)

print(
    len(trip_data_raw.loc[~pd.isna(trip_data_raw['pickup_centroid_latitude'])
                          & pd.isna(trip_data_raw['pickup_census_tract'])]),
    "number of columns were pickup_centroid_latitude and pickup_centroid_longitude and pickup_centroid_location are filled but census trackt not\n"
)
# Out:
# 0 number of columns were either pickup_centroid_latitude xor pickup_centroid_longitude is filled
#
# 0 number of columns were either pickup_centroid_latitude xor pickup_centroid_location is filled
#
# 271334 number of columns were either pickup_centroid_latitude and pickup_centroid_longitude and pickup_centroid_location are filled
#
# 229 number of columns were pickup_centroid_latitude and pickup_centroid_longitude and pickup_centroid_location are not filled but census trackt
#
# 89464 number of columns were pickup_centroid_latitude and pickup_centroid_longitude and pickup_centroid_location are filled but census trackt not

# %%
print(
    len(trip_data_raw.loc[
        ~pd.isna(trip_data_raw['dropoff_centroid_latitude'])
        ^ ~pd.isna(trip_data_raw['dropoff_centroid_longitude'])]),
    "number of columns were either dropoff_centroid_latitude xor dropoff_centroid_longitude is filled\n"
)
print(
    len(trip_data_raw.loc[
        ~pd.isna(trip_data_raw['dropoff_centroid_latitude'])
        ^ ~pd.isna(trip_data_raw['dropoff_centroid_location'])]),
    "number of columns were either dropoff_centroid_latitude xor dropoff_centroid_location is filled\n"
)
print(
    len(trip_data_raw.loc[
        ~pd.isna(trip_data_raw['dropoff_centroid_latitude'])
        & ~pd.isna(trip_data_raw['dropoff_centroid_location'])]),
    "number of columns were either dropoff_centroid_latitude and dropoff_centroid_longitude and dropoff_centroid_location are filled\n"
)
print(
    len(trip_data_raw.loc[pd.isna(trip_data_raw['dropoff_centroid_latitude'])
                          & ~pd.isna(trip_data_raw['dropoff_census_tract'])]),
    "number of columns were dropoff_centroid_latitude and dropoff_centroid_longitude and dropoff_centroid_location are not filled but census trackt\n"
)

print(
    len(trip_data_raw.loc[~pd.isna(trip_data_raw['dropoff_centroid_latitude'])
                          & pd.isna(trip_data_raw['dropoff_census_tract'])]),
    "number of columns were dropoff_centroid_latitude and dropoff_centroid_longitude and dropoff_centroid_location are filled but census trackt %notebook\n"
)
# Out:
# 0 number of columns were either dropoff_centroid_latitude xor dropoff_centroid_longitude is filled
#
# 0 number of columns were either dropoff_centroid_latitude xor dropoff_centroid_location is filled
#
# 265461 number of columns were either dropoff_centroid_latitude and dropoff_centroid_longitude and dropoff_centroid_location are filled
#
# 555 number of columns were dropoff_centroid_latitude and dropoff_centroid_longitude and dropoff_centroid_location are not filled but census trackt
#
# 85070 number of columns were dropoff_centroid_latitude and dropoff_centroid_longitude and dropoff_centroid_location are filled but census trackt %notebook

# %% [markdown]
# **Summary**
# * If centroid_location is NaN so are centroid_latitude and centroide_longitude and the other way around
# * However, there is census tract data where latitude, longitude and location data is NaN. But is not much so that can be    neglected and the NaN rows can be deleted
# * there is more pickoff data than dropoff -> dropoff is not need for demand prediction task
# * around ~2 Millionen rows have missing location data: 10% of the overall dataset

# %% [markdown]
# **Drop missing geographical data**
#
# as described above in section 4.1 we cannot recover the missing data (expect for the ~40000)
# so we decided to drop the NaN columns

# %%
# as described above in section 4.1 we cannot recover the missing data (expect for the ~40000)
# so we decided to drop the NaN columns

trip_data_raw.dropna(subset=['dropoff_centroid_location'], inplace=True)
trip_data_raw.dropna(subset=['pickup_centroid_location'], inplace=True)
print(len(trip_data_raw))
# Out:
# 262349

# %%
trip_data_raw.drop([
    'dropoff_centroid_latitude', 'pickup_centroid_latitude',
    'pickup_centroid_longitude', 'dropoff_centroid_longitude'
],
                   axis=1,
                   inplace=True)

# %% [markdown]
# ### Convert to geopandas column

# %%
trip_data_raw['dropoff_centroid_location'] = trip_data_raw[
    'dropoff_centroid_location'].apply(
        lambda x: Point(ast.literal_eval(x).get('coordinates')))
trip_data_raw['pickup_centroid_location'] = trip_data_raw[
    'pickup_centroid_location'].apply(
        lambda x: Point(ast.literal_eval(x).get('coordinates')))

# %%
trip_data_raw_geo = gpd.GeoDataFrame(trip_data_raw,
                                     geometry='pickup_centroid_location')
trip_data_raw_geo.set_geometry('dropoff_centroid_location', inplace=True)

# %% [markdown]
# ### Create H3 discretization

# %%
trip_data_raw_geo['h3_res_6'] = trip_data_raw_geo.apply(
    lambda row: h3.geo_to_h3(lat=row['pickup_centroid_location'].y,
                             lng=row['pickup_centroid_location'].x,
                             resolution=6),
    axis=1)

trip_data_raw_geo['h3_res_4'] = trip_data_raw_geo.apply(
    lambda row: h3.geo_to_h3(lat=row['pickup_centroid_location'].y,
                             lng=row['pickup_centroid_location'].x,
                             resolution=4),
    axis=1)

trip_data_raw_geo['h3_res_8'] = trip_data_raw_geo.apply(
    lambda row: h3.geo_to_h3(lat=row['pickup_centroid_location'].y,
                             lng=row['pickup_centroid_location'].x,
                             resolution=8),
    axis=1)

# %%
print(trip_data_raw_geo['h3_res_4'].nunique())
print(trip_data_raw_geo['h3_res_6'].nunique())
print(trip_data_raw_geo['h3_res_8'].nunique())
# Out:
# 4
# 27
# 195

# %% [markdown]
# ### Visualize Data

# %%
figure, ax = plt.subplots(figsize=(16, 9))

figure_pickup_location = trip_data_raw_geo[['pickup_centroid_location']]
figure_dropoff_location = trip_data_raw_geo[['dropoff_centroid_location']]

figure_pickup_location = figure_pickup_location.set_geometry(
    'pickup_centroid_location')
figure_dropoff_location = figure_dropoff_location.set_geometry(
    'dropoff_centroid_location')

figure_pickup_location.crs = 'epsg:4326'
figure_dropoff_location.crs = 'epsg:4326'

figure_pickup_location = figure_pickup_location.to_crs(epsg=3857)
figure_dropoff_location = figure_dropoff_location.to_crs(epsg=3857)

figure_pickup_location.plot(color='green', ax=ax, marker='o', markersize=7)
figure_dropoff_location.plot(color='blue',
                             ax=ax,
                             marker='o',
                             markersize=7,
                             alpha=0.01)

#ctx.add_basemap(ax=ax, zoom=12)

# %%
visualize_hexagons_6 = trip_data_raw_geo[['h3_res_6']].copy()
visualize_hexagons_6['number'] = 1

visualize_hexagons_6 = visualize_hexagons_6.groupby(['h3_res_6'],
                                                    as_index=False).sum()

visualize_hexagons_4 = trip_data_raw_geo[['h3_res_4']].copy()
visualize_hexagons_4['number'] = 1

visualize_hexagons_4 = visualize_hexagons_4.groupby(['h3_res_4'],
                                                    as_index=False).sum()

visualize_hexagons_8 = trip_data_raw_geo[['h3_res_8']].copy()
visualize_hexagons_8['number'] = 1

visualize_hexagons_8 = visualize_hexagons_8.groupby(['h3_res_8'],
                                                    as_index=False).sum()

# %%
visualize_hexagons_6['h3_res_6_geo'] = visualize_hexagons_6['h3_res_6'].apply(
    lambda x: shape({
        'type': 'Polygon',
        'coordinates': [h3.h3_to_geo_boundary(x, geo_json=True)],
        'properties': ''
    }))
visualize_hexagons_4['h3_res_4_geo'] = visualize_hexagons_4['h3_res_4'].apply(
    lambda x: shape({
        'type': 'Polygon',
        'coordinates': [h3.h3_to_geo_boundary(x, geo_json=True)],
        'properties': ''
    }))
visualize_hexagons_8['h3_res_8_geo'] = visualize_hexagons_8['h3_res_8'].apply(
    lambda x: shape({
        'type': 'Polygon',
        'coordinates': [h3.h3_to_geo_boundary(x, geo_json=True)],
        'properties': ''
    }))

# %%
visualize_hexagons_6 = visualize_hexagons_6.set_geometry('h3_res_6_geo')
visualize_hexagons_6.crs = 'epsg:4326'

visualize_hexagons_6 = visualize_hexagons_6.to_crs(epsg=3857)

visualize_hexagons_4 = visualize_hexagons_4.set_geometry('h3_res_4_geo')
visualize_hexagons_4.crs = 'epsg:4326'

visualize_hexagons_4 = visualize_hexagons_4.to_crs(epsg=3857)

visualize_hexagons_8 = visualize_hexagons_8.set_geometry('h3_res_8_geo')
visualize_hexagons_8.crs = 'epsg:4326'

visualize_hexagons_8 = visualize_hexagons_8.to_crs(epsg=3857)

# %%
figure, ax = plt.subplots(2, 2, figsize=(16, 16))

visualize_hexagons_6.set_geometry('h3_res_6_geo').plot(ax=ax[0, 0],
                                                       edgecolor='black',
                                                       linewidth=1.0,
                                                       alpha=0.3)

figure_pickup_location.plot(color='green',
                            ax=ax[0, 0],
                            marker='o',
                            markersize=7)

#ctx.add_basemap(ax=ax[0,0], zoom=12)

visualize_hexagons_6.set_geometry('h3_res_6_geo').plot(ax=ax[0, 1],
                                                       edgecolor='black',
                                                       linewidth=1.0,
                                                       column='number',
                                                       cmap='Reds',
                                                       alpha=0.6)

#ctx.add_basemap(ax=ax[0,1], zoom=12)

visualize_hexagons_8.set_geometry('h3_res_8_geo').plot(ax=ax[1, 0],
                                                       edgecolor='black',
                                                       linewidth=1.0,
                                                       alpha=0.3)

#ctx.add_basemap(ax=ax[1,0], zoom=12)

visualize_hexagons_4.set_geometry('h3_res_4_geo').plot(ax=ax[1, 1],
                                                       edgecolor='black',
                                                       linewidth=1.0,
                                                       alpha=0.3)

#ctx.add_basemap(ax=ax[1,1], zoom=12)

# %% [markdown]
# A resolution of 6 seems reasonable, a resolution of 4 maybe to coarse and a resolution of 8 almost to fine

# %% [markdown]
# ## Check for duplicates

# %%
print(trip_data_raw_geo["trip_id"].nunique()
      )  #20695512 entries in whole dataset -> no duplicates
# Out:
# 262349

# %% [markdown]
# ## Handling missing values

# %% [markdown]
# **Missing Trip stimestamp**
# only 349 rows so they can be dropped

# %%
print("NaN Values trip_start_timestamp",
      trip_data_raw_geo["trip_start_timestamp"].isna().sum(), "\n")
print("NaN Values trip_end_timestamp",
      trip_data_raw_geo["trip_end_timestamp"].isna().sum(), "\n")
print("NaN Values trip_seconds",
      trip_data_raw_geo["trip_seconds"].isna().sum(), "\n")
print("NaN Values trip_miles", trip_data_raw_geo["trip_miles"].isna().sum(),
      "\n")
print("NaN Values fare", trip_data_raw_geo["fare"].isna().sum(), "\n")
# Out:
# NaN Values trip_start_timestamp 0
#
# NaN Values trip_end_timestamp 0
#
# NaN Values trip_seconds 6
#
# NaN Values trip_miles 8
#
# NaN Values fare 12

# %%
trip_data_raw_geo.describe()
# Out:
#         trip_seconds     trip_miles  pickup_census_tract  \
# count  262343.000000  262341.000000         1.795630e+05
# mean      648.335538       2.914330         1.703138e+10
# std      1053.953646       4.886272         3.371028e+05
# min         0.000000       0.000000         1.703101e+10
# 25%       300.000000       0.600000         1.703108e+10
# 50%       480.000000       1.200000         1.703128e+10
# 75%       780.000000       2.700000         1.703184e+10
# max     86340.000000     783.700000         1.703198e+10
#
#        dropoff_census_tract  pickup_community_area  dropoff_community_area  \
# count          1.795630e+05          262138.000000           261575.000000
# mean           1.703135e+10              23.561559               21.048609
# std            3.252032e+05              19.228699               16.967207
# min            1.703101e+10               1.000000                1.000000
# 25%            1.703108e+10               8.000000                8.000000
# 50%            1.703128e+10              24.000000               16.000000
# 75%            1.703183e+10              32.000000               32.000000
# max            1.703198e+10              77.000000               77.000000
#
#                 fare           tips          tolls         extras  \
# count  262337.000000  262337.000000  191577.000000  262337.000000
# mean       11.968644       1.258200       0.004193       0.734377
# std        54.858614       2.363404       0.461011       3.473828
# min         0.000000       0.000000       0.000000       0.000000
# 25%         5.500000       0.000000       0.000000       0.000000
# 50%         7.250000       0.000000       0.000000       0.000000
# 75%        11.500000       2.000000       0.000000       1.000000
# max      8000.900000     162.750000      75.000000    1414.120000
#
#           trip_total
# count  262337.000000
# mean       14.062633
# std        55.643768
# min         0.000000
# 25%         6.500000
# 50%         9.000000
# 75%        13.500000
# max      8050.970000

# %% [markdown]
# ## Check validity/ handle outliers

# %% [markdown]
# ## Join Datasets

# %%
trip_data_raw_geo.sort_values(by='trip_start_timestamp', inplace=True)
weather_data.sort_values(by='date', inplace=True)

merged_data = pd.merge_asof(left=trip_data_raw_geo,
                            right=weather_data.loc[:, ('date', 'temperature',
                                                       'precipitation')],
                            left_on='trip_start_timestamp',
                            right_on='date',
                            direction='nearest')

# %% [markdown]
# # Feature Engineering & Selection

# %% [markdown]
# ## Prediction Task

# %%
prediction_data_raw = merged_data.loc[:, ('trip_start_timestamp', 'h3_res_4',
                                          'h3_res_6', 'h3_res_8',
                                          'temperature', 'precipitation')]
prediction_data_raw["number_of_trips"] = 1
prediction_data_raw['weekday'] = prediction_data_raw[
    'trip_start_timestamp'].apply(lambda x: x.day)
prediction_data_raw['month'] = prediction_data_raw[
    'trip_start_timestamp'].apply(lambda x: x.month)

time_periods = [1, 2, 6, 24]
resolution = ['h3_res_4', 'h3_res_6', 'h3_res_8']

# %%
prediction_data_raw.head(5)
# Out:
#   trip_start_timestamp         h3_res_4         h3_res_6         h3_res_8  \
# 0  2018-01-01 00:15:00  842664dffffffff  862664c1fffffff  882664c1e1fffff
# 1  2018-01-01 00:15:00  842664dffffffff  862664c1fffffff  882664c1e1fffff
# 2  2018-01-01 00:15:00  842664dffffffff  862664c1fffffff  882664c1e5fffff
# 3  2018-01-01 00:15:00  842664dffffffff  862664c1fffffff  882664c1edfffff
# 4  2018-01-01 00:15:00  842664dffffffff  862664c1fffffff  882664c1e9fffff
#
#    temperature  precipitation  number_of_trips  weekday  month
# 0   -20.555556            0.0                1        1      1
# 1   -20.555556            0.0                1        1      1
# 2   -20.555556            0.0                1        1      1
# 3   -20.555556            0.0                1        1      1
# 4   -20.555556            0.0                1        1      1

# %% [markdown]
# ### Create different Time Bins

# %%
prediction_data = {}
for period in time_periods:
    dict_time_bucket = {}
    for res in resolution:
        df = prediction_data_raw.loc[:, ('trip_start_timestamp', 'temperature',
                                         'precipitation', 'number_of_trips',
                                         'weekday', 'month', res)]
        df['trip_start_timestamp'] = df['trip_start_timestamp'].apply(
            lambda x: x.replace(minute=0, hour=(x.hour // period) * period))
        df['hour'] = df['trip_start_timestamp'].apply(lambda x: x.hour)
        df = df.groupby(['trip_start_timestamp', res], as_index=True).agg({
            'temperature':
            'mean',
            'precipitation':
            'mean',
            'number_of_trips':
            'sum',
            'weekday':
            'mean',
            'month':
            'mean',
            'hour':
            'mean'
        })
        df.reset_index(level=res, inplace=True)
        dict_time_bucket[res] = df

    prediction_data[period] = dict_time_bucket

# %%
prediction_data.get(1).get('h3_res_4').head(5)
# Out:
#                              h3_res_4  temperature  precipitation  \
# trip_start_timestamp
# 2018-01-01 00:00:00   8426645ffffffff   -20.555556            0.0
# 2018-01-01 00:00:00   842664dffffffff   -20.555556            0.0
# 2018-01-01 00:00:00   8427593ffffffff   -20.555556            0.0
# 2018-01-01 01:00:00   8426645ffffffff   -18.333333            0.0
# 2018-01-01 01:00:00   842664dffffffff   -19.374470            0.0
#
#                       number_of_trips  weekday  month  hour
# trip_start_timestamp
# 2018-01-01 00:00:00                 2        1      1     0
# 2018-01-01 00:00:00              2321        1      1     0
# 2018-01-01 00:00:00                35        1      1     0
# 2018-01-01 01:00:00                 2        1      1     1
# 2018-01-01 01:00:00              4192        1      1     1

# %% [markdown]
# ### Create Cyclical Time Features with Sine and Cosine Transformation

# %%
for periods in prediction_data.keys():
    for res in prediction_data.get(periods).keys():
        df = prediction_data.get(periods).get(res)
        if (periods != 24):
            df["hour_sin"] = np.sin(2 * np.pi * df["hour"] / df["hour"].max())
            df["hour_cos"] = np.cos(2 * np.pi * df["hour"] / df["hour"].max())

        df["weekday_sin"] = np.sin(2 * np.pi * df["weekday"] /
                                   df["weekday"].max())
        df["weekday_cos"] = np.cos(2 * np.pi * df["weekday"] /
                                   df["weekday"].max())

        df["weekday_sin"] = np.sin(2 * np.pi * df["month"] / df["month"].max())
        df["weekday_cos"] = np.cos(2 * np.pi * df["month"] / df["month"].max())

# %%
prediction_data.get(1).get('h3_res_4').head(5)
# Out:
#                              h3_res_4  temperature  precipitation  \
# trip_start_timestamp
# 2018-01-01 00:00:00   8426645ffffffff   -20.555556            0.0
# 2018-01-01 00:00:00   842664dffffffff   -20.555556            0.0
# 2018-01-01 00:00:00   8427593ffffffff   -20.555556            0.0
# 2018-01-01 01:00:00   8426645ffffffff   -18.333333            0.0
# 2018-01-01 01:00:00   842664dffffffff   -19.374470            0.0
#
#                       number_of_trips  weekday  month  hour  hour_sin  \
# trip_start_timestamp
# 2018-01-01 00:00:00                 2        1      1     0  0.000000
# 2018-01-01 00:00:00              2321        1      1     0  0.000000
# 2018-01-01 00:00:00                35        1      1     0  0.000000
# 2018-01-01 01:00:00                 2        1      1     1  0.269797
# 2018-01-01 01:00:00              4192        1      1     1  0.269797
#
#                       hour_cos   weekday_sin  weekday_cos
# trip_start_timestamp
# 2018-01-01 00:00:00   1.000000 -2.449294e-16          1.0
# 2018-01-01 00:00:00   1.000000 -2.449294e-16          1.0
# 2018-01-01 00:00:00   1.000000 -2.449294e-16          1.0
# 2018-01-01 01:00:00   0.962917 -2.449294e-16          1.0
# 2018-01-01 01:00:00   0.962917 -2.449294e-16          1.0

# %% [markdown]
# ### Create Lagged Time Features

# %%
def get_cancer(row_index, area, area_column):
    if row_index in df.index:
        trips = df.loc[(df.index == row_index) & (df[area_column] == area),
                       'number_of_trips']
        if len(trips) == 0:
            return None
        else:
            return trips[0]

# %%
for periods in prediction_data.keys():
    for res in prediction_data.get(periods).keys():
        df = prediction_data.get(periods).get(res)
        if periods != 24:
            df["lagged_" + str(periods) +
               "h"] = df.apply(lambda row: get_cancer(
                   row.name - pd.Timedelta(hours=periods), row[res], res),
                               axis=1)
        df["lagged_1day"] = df.apply(lambda row: get_cancer(
            row.name - pd.Timedelta(days=1), row[res], res),
                                     axis=1)

# %%
prediction_data.get(1).get('h3_res_4').head(5)
# Out:
#                              h3_res_4  temperature  precipitation  \
# trip_start_timestamp
# 2018-01-01 00:00:00   8426645ffffffff   -20.555556            0.0
# 2018-01-01 00:00:00   842664dffffffff   -20.555556            0.0
# 2018-01-01 00:00:00   8427593ffffffff   -20.555556            0.0
# 2018-01-01 01:00:00   8426645ffffffff   -18.333333            0.0
# 2018-01-01 01:00:00   842664dffffffff   -19.374470            0.0
#
#                       number_of_trips  weekday  month  hour  hour_sin  \
# trip_start_timestamp
# 2018-01-01 00:00:00                 2        1      1     0  0.000000
# 2018-01-01 00:00:00              2321        1      1     0  0.000000
# 2018-01-01 00:00:00                35        1      1     0  0.000000
# 2018-01-01 01:00:00                 2        1      1     1  0.269797
# 2018-01-01 01:00:00              4192        1      1     1  0.269797
#
#                       hour_cos   weekday_sin  weekday_cos  lagged_1h  \
# trip_start_timestamp
# 2018-01-01 00:00:00   1.000000 -2.449294e-16          1.0        NaN
# 2018-01-01 00:00:00   1.000000 -2.449294e-16          1.0        NaN
# 2018-01-01 00:00:00   1.000000 -2.449294e-16          1.0        NaN
# 2018-01-01 01:00:00   0.962917 -2.449294e-16          1.0        2.0
# 2018-01-01 01:00:00   0.962917 -2.449294e-16          1.0     2321.0
#
#                       lagged_1day
# trip_start_timestamp
# 2018-01-01 00:00:00           NaN
# 2018-01-01 00:00:00           NaN
# 2018-01-01 00:00:00           NaN
# 2018-01-01 01:00:00           NaN
# 2018-01-01 01:00:00           NaN

# %% [markdown]
# ### Visualize Relationship between Predictors and dependent Variable

# %% [markdown]
# # Export new Datasets
