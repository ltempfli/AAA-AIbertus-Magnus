# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"></ul></div>

# %%
import pandas as pd
import seaborn as sns
import matplotlib as plt

# %%
trip_data_raw = pd.read_csv('chicago_taxi_data.csv', index_col=None, nrows=20, dtype={
    'trip_ID' : 'str',
    'taxi_ID' : 'str',
#    'trip_start_timestamp' : 'datetime64[ms]',
    'payment_type' : 'category',
    'company' : 'category'
})

# %%
trip_data_raw.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 23 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   trip_id                     20 non-null     object
#  1   taxi_id                     20 non-null     object
#  2   trip_start_timestamp        20 non-null     object
#  3   trip_end_timestamp          20 non-null     object
#  4   trip_seconds                20 non-null     int64
#  5   trip_miles                  20 non-null     float64
#  6   pickup_census_tract         7 non-null      float64
#  7   dropoff_census_tract        7 non-null      float64
#  8   pickup_community_area       9 non-null      float64
#  9   dropoff_community_area      9 non-null      float64
#  10  fare                        20 non-null     float64
#  11  tips                        20 non-null     float64
#  12  tolls                       20 non-null     float64
# ...

# %%
trip_data_raw.head(20)
# Out:
#                                      trip_id  \
# 0   d7bf7332e89c6597d682495ac78a325c2ed4183f
# 1   c8769473b60b18f700afce0f812f6d80c3616ca7
# 2   c52d1cd141c3036d091ed85cbf7a973cc5c1243e
# 3   b5714d1d2118642f789ab0fec542f597f986c251
# 4   0352e306e7cc33a455c3be20764ad2ce9881216a
# 5   594e15b562a96bd7cafac7211fb71ff4331ee803
# 6   2896540c849ebc75c05af74af4b969759eaa5fa3
# 7   71b0b8528bb56e921997c6de6190257fe2e58dcd
# 8   047773cc8210996a8f88ad023c79c86bba5423de
# 9   80447e42e7ad6f32607bdcbba79725b3ea8bc094
# 10  a6673cb2888d07e963a35fedd3a635ac1b11c3d4
# 11  0a0a2ca50df85134ce34f0c2c7bda6e78ca2a52c
# 12  7c46253c55f14a47b0bdd41baa1abc0366d64c58
# 13  ac1fae1544d7804f13fbf657cb058ba91a983fea
# 14  b7e939ebeb25eee245afd346ff63adeb0139e6d7
# 15  29f96067e9339e477e983efddd6395a2a8557c45
# 16  967a2dad921818b54a19b27a9c67310f7cfb9f2c
# 17  a6ecf116e5ed732519617bf003100af806fa1f02
# 18  e4bcdde34928852b0d8ed4641f4c0533e06a29ab
# 19  649cae1facf2431d6e5578fec8cadfef46d79841
#
# ...

# %% [markdown]
# trip_id,taxi_id,trip_start_timestamp,trip_end_timestamp,trip_seconds,trip_miles,fare,tips,tolls,extras,trip_total,payment_type,company,pickup_centroid_latitude,pickup_centroid_longitude,pickup_centroid_location,dropoff_centroid_latitude,dropoff_centroid_longitude,dropoff_centroid_location

# %%
trip_data_raw.columns
# Out:
# Index(['trip_id', 'taxi_id', 'trip_start_timestamp', 'trip_end_timestamp',
#        'trip_seconds', 'trip_miles', 'pickup_census_tract',
#        'dropoff_census_tract', 'pickup_community_area',
#        'dropoff_community_area', 'fare', 'tips', 'tolls', 'extras',
#        'trip_total', 'payment_type', 'company', 'pickup_centroid_latitude',
#        'pickup_centroid_longitude', 'pickup_centroid_location',
#        'dropoff_centroid_latitude', 'dropoff_centroid_longitude',
#        'dropoff_centroid_location'],
#       dtype='object')
